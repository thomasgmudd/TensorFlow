# %% [markdown]
# ***Sequence prediction with CNN and LR optimization***
#
# dataset is NASDAQ open and close 40 year history

# %%
import csv
import pickle
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from dataclasses import dataclass

# %% [markdown]
# Begin by looking at the structure of the csv that contains the data:

# %%
NASDAQ_CSV = 'd:/data/stocks/nasdaq1984.csv'

with open(NASDAQ_CSV, 'r') as csvfile:
    print(f"Header looks like this           :  {csvfile.readline()}")    
    print(f"First data point looks like this :  {csvfile.readline()}")
    print(f"Second data point looks like this:  {csvfile.readline()}")
# Out:
# Header looks like this           :  Date,Open,High,Low,Close,Adj Close,Volume
#
# First data point looks like this :  10/11/1984,244.199997,244.699997,244.199997,244.699997,244.699997,62860000
#
# Second data point looks like this:  10/12/1984,245.5,246.199997,245.5,246.199997,246.199997,58860000

# %% [markdown]
# **Create plot function**

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %% [markdown]
# **Parse the .csv data**

# %%
def parse_data_from_file(filename):
    
    date = []
    close = []
    volume= []

    with open(filename) as csvfile:
       
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)
     
        for record in reader:
            date.append(record[0])
            close.append(float(record[4]))
            volume.append(float(record[6]))
 
        days=list(range(0,len(date)))
    
    print(len(days), len(date))
            
    return days, date, close, volume

# %% [markdown]
# **Create Globals**

# %%
# Test your function and save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    #NASDAQ_CSV = 'd:/data/stocks/10yearnasdaq.csv'
    times, date, close,volume = parse_data_from_file(NASDAQ_CSV)
    TIME = np.array(times)
    #SERIES = np.flip(np.array(np.divide(close,15000)))
    SERIES=np.array(np.divide(close,15000))
    VOLUME=np.array(np.divide(volume,6e7))
    SPLIT_TIME = 9604-251
    WINDOW_SIZE = 64
    BATCH_SIZE = 1024
    SHUFFLE_BUFFER_SIZE = 1000


plt.figure(figsize=(10, 6))
plot_series(G.TIME, G.SERIES)
plt.show()
# Out:
# 9604 9604

# %% [markdown]
# **Do Train and Validation split**

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    time_valid = time[time_step:]
    series_train = series[:time_step]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid


def train_val_volume(volume,time_step=G.SPLIT_TIME):
    volume_train = volume[:time_step]
    volume_valid = volume[time_step:]
    
    return volume_train, volume_valid


# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)
volume_train, volume_valid = train_val_volume(G.VOLUME)

print ('First 3 [time] [train]  ', time_train[0:3], series_train[0:3])
print ('Split at   :',G.SPLIT_TIME)
print ('WINDOW_SIZE:',G.WINDOW_SIZE)
print ('All               :',np.shape(G.TIME))
print ('Train Seq         :',np.shape(time_train))
print ('Train Volume      :',np.shape(volume_train))
print ('Validation Seq    :',np.shape(time_valid))
print ('Validation Volume :',np.shape(volume_valid))
# Out:
# First 3 [time] [train]   [0 1 2] [0.01631333 0.01641333 0.01651333]
# Split at   : 9353
# WINDOW_SIZE: 64
# All               : (9604,)
# Train Seq         : (9353,)
# Train Volume      : (9353,)
# Validation Seq    : (251,)
# Validation Volume : (251,)

# %% [markdown]
# ***Create windowed dataset***

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    #ds = ds.shuffle(shuffle_buffer)  # uncomment shuffle for prod
    ds = ds.map(lambda w: (w[:-1], w[-1]))
    ds = ds.batch(batch_size).prefetch(1)
    return ds

def flag_dataset(flags,batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    ds=tf.data.Dataset.from_tensor_slices(volume_train)
    ds = ds.batch(batch_size).prefetch(1)
    return ds


# Apply the transformation to the training set
train_set = windowed_dataset(series_train, window_size=64, batch_size=G.BATCH_SIZE, shuffle_buffer=1000)
valid_set = windowed_dataset(series_valid, window_size=64, batch_size=G.BATCH_SIZE, shuffle_buffer=1000)
train_vol = flag_dataset(train_vol)


print ('train set shape: ',np.shape(train_set))
print (type(train_set),'\n')
for elem in train_set:
    print(elem[0],'\n\n')
    print('current data shape       : ',np.shape(elem[0])) 
    x=tf.expand_dims(elem[0], axis=-1)
    print('need this shape for model: ',np.shape(x))
    break
    
for elem in train_vol:
    print('\n\n',elem,'\n\n')
    print('current data shape       : ',np.shape(elem)) 
    x=tf.expand_dims(elem, axis=-1)
    x=tf.expand_dims(x, axis=-1)
    print('need this shape for model: ',np.shape(x))
    break
# Out:
# train set shape:  ()
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>
#
# tf.Tensor(
# [[0.01631333 0.01641333 0.01651333 ... 0.01648667 0.01671333 0.01681333]
#  [0.01641333 0.01651333 0.01648667 ... 0.01671333 0.01681333 0.01703333]
#  [0.01651333 0.01648667 0.01647333 ... 0.01681333 0.01703333 0.01718667]
#  ...
#  [0.02568    0.02545333 0.02552    ... 0.02613333 0.02626667 0.02647333]
#  [0.02545333 0.02552    0.0255     ... 0.02626667 0.02647333 0.02653333]
#  [0.02552    0.0255     0.02549333 ... 0.02647333 0.02653333 0.02661333]], shape=(1024, 64), dtype=float64)
#
#
# current data shape       :  (1024, 64)
# need this shape for model:  (1024, 64, 1)
#
#
#  tf.Tensor([1.04766667 0.981      1.03033333 ... 1.84016667 2.04433333 1.76683333], shape=(1024,), dtype=float64)
#
#
# current data shape       :  (1024,)
# need this shape for model:  (1024, 1, 1)

# %% [markdown]
# **Define the tuning model**

# %%
def create_uncompiled_model(modelnum=0):


    if modelnum==0:
        model = tf.keras.models.Sequential([ 
            tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None]),
            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
            tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
            tf.keras.layers.Dense(1)])
        
    elif modelnum==1:
        model = tf.keras.models.Sequential([
             tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None]), # adds the required depth dim
             tf.keras.layers.Conv1D(filters=64, kernel_size=2, strides=1, padding='same', activation='relu',input_shape=(64,1) ),
             tf.keras.layers.LSTM(64, return_sequences=True),
             tf.keras.layers.LSTM(64),
             tf.keras.layers.Dense(1)]) 
    
    elif modelnum==2:
        model = tf.keras.models.Sequential([
             tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None]), # adds the required depth dim
             tf.keras.layers.LSTM(64, return_sequences=True),
             tf.keras.layers.LSTM(64, return_sequences=True),
             tf.keras.layers.LSTM(64),
             tf.keras.layers.Dense(32),
             tf.keras.layers.Dense(1)]) 
    
    return model

# %%
# Test your uncompiled model
print("window:",G.WINDOW_SIZE)
print("batch :",G.BATCH_SIZE)
print("train_set:",train_set)
for element in train_set:
    print("train_set element shape: ",np.shape(element[0]))
    break

uncompiled_model = create_uncompiled_model(2)
uncompiled_model.summary()

for element in train_set:
    uncompiled_model.predict(element[0])

try:
    uncompiled_model.predict(train_set)
except:
    print("\Fail")
else:
    print("\nSuccess")
# Out:
# window: 64
# batch : 1024
# train_set: <PrefetchDataset shapes: ((None, None), (None,)), types: (tf.float64, tf.float64)>
# train_set element shape:  (1024, 64)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_2 (Lambda)            (None, None, 1)           0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, None, 64)          16896
# _________________________________________________________________
# lstm_6 (LSTM)                (None, None, 64)          33024
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 85,057
# Trainable params: 85,057
# Non-trainable params: 0
# _________________________________________________________________
#
# Success

# %% [markdown]
# **Test a range of learning rates**
# - tf.keras.optimizers.Adam
# - tf.keras.optimizers.SGD with a momentum of 0.9

# %%
def adjust_learning_rate(dataset):
    
    model = create_uncompiled_model()
    
    lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch / 20))

    optimizer = tf.keras.optimizers.SGD(learning_rate=5e-5,momentum=.5)

    model.compile(loss=tf.keras.losses.Huber(),
                  optimizer=optimizer, 
                  metrics=["mae"]) 
    
    history = model.fit(dataset, epochs=100, callbacks=[lr_schedule])
    
    return history

# %%
# Run the training with dynamic LR
lr_history = adjust_learning_rate(train_set)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 5s 64ms/step - loss: 0.0475 - mae: 0.2166
# Epoch 2/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0470 - mae: 0.2146
# Epoch 3/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0464 - mae: 0.2123
# Epoch 4/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0458 - mae: 0.2097
# Epoch 5/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0452 - mae: 0.2068
# Epoch 6/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0445 - mae: 0.2036
# Epoch 7/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0437 - mae: 0.2000
# Epoch 8/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0428 - mae: 0.1960
# Epoch 9/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0419 - mae: 0.1916
# Epoch 10/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0409 - mae: 0.1870
# Epoch 11/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0398 - mae: 0.1824
# Epoch 12/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0386 - mae: 0.1781
# Epoch 13/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0374 - mae: 0.1738
# Epoch 14/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0361 - mae: 0.1694
# Epoch 15/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0347 - mae: 0.1650
# Epoch 16/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0333 - mae: 0.1608
# Epoch 17/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0319 - mae: 0.1565
# Epoch 18/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0304 - mae: 0.1520
# Epoch 19/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0289 - mae: 0.1475
# Epoch 20/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0274 - mae: 0.1433
# Epoch 21/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0260 - mae: 0.1394
# Epoch 22/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0247 - mae: 0.1360
# Epoch 23/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0234 - mae: 0.1333
# Epoch 24/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0223 - mae: 0.1318
# Epoch 25/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0214 - mae: 0.1317
# Epoch 26/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0206 - mae: 0.1329
# Epoch 27/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0200 - mae: 0.1353
# Epoch 28/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0195 - mae: 0.1385
# Epoch 29/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.0191 - mae: 0.1422
# Epoch 30/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0189 - mae: 0.1459
# Epoch 31/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0188 - mae: 0.1493
# Epoch 32/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0187 - mae: 0.1522
# Epoch 33/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0185 - mae: 0.1544
# Epoch 34/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0184 - mae: 0.1558
# Epoch 35/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0181 - mae: 0.1563
# Epoch 36/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0177 - mae: 0.1558
# Epoch 37/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0172 - mae: 0.1545
# Epoch 38/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0166 - mae: 0.1522
# Epoch 39/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0158 - mae: 0.1490
# Epoch 40/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0149 - mae: 0.1449
# Epoch 41/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0139 - mae: 0.1401
# Epoch 42/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0128 - mae: 0.1344
# Epoch 43/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0116 - mae: 0.1279
# Epoch 44/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0103 - mae: 0.1205
# Epoch 45/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0089 - mae: 0.1120
# Epoch 46/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0075 - mae: 0.1023
# Epoch 47/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0060 - mae: 0.0913
# Epoch 48/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0045 - mae: 0.0790
# Epoch 49/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0031 - mae: 0.0653
# Epoch 50/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0019 - mae: 0.0509
# Epoch 51/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0010 - mae: 0.0366
# Epoch 52/100
# 10/10 [==============================] - 1s 74ms/step - loss: 4.6520e-04 - mae: 0.0241
# Epoch 53/100
# 10/10 [==============================] - 1s 75ms/step - loss: 1.9689e-04 - mae: 0.0152
# Epoch 54/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.2769e-04 - mae: 0.0104
# Epoch 55/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.4384e-04 - mae: 0.0117
# Epoch 56/100
# 10/10 [==============================] - 1s 75ms/step - loss: 1.7468e-04 - mae: 0.0137
# Epoch 57/100
# 10/10 [==============================] - 1s 75ms/step - loss: 1.9735e-04 - mae: 0.0147
# Epoch 58/100
# 10/10 [==============================] - 1s 80ms/step - loss: 2.1248e-04 - mae: 0.0152
# Epoch 59/100
# 10/10 [==============================] - 1s 76ms/step - loss: 2.2472e-04 - mae: 0.0157
# Epoch 60/100
# 10/10 [==============================] - 1s 77ms/step - loss: 2.3649e-04 - mae: 0.0162
# Epoch 61/100
# 10/10 [==============================] - 1s 77ms/step - loss: 2.4846e-04 - mae: 0.0167
# Epoch 62/100
# 10/10 [==============================] - 1s 80ms/step - loss: 2.6140e-04 - mae: 0.0173
# Epoch 63/100
# 10/10 [==============================] - 1s 83ms/step - loss: 2.7794e-04 - mae: 0.0180
# Epoch 64/100
# 10/10 [==============================] - 1s 83ms/step - loss: 3.0370e-04 - mae: 0.0189
# Epoch 65/100
# 10/10 [==============================] - 1s 76ms/step - loss: 3.4781e-04 - mae: 0.0208
# Epoch 66/100
# 10/10 [==============================] - 1s 78ms/step - loss: 4.2359e-04 - mae: 0.0238
# Epoch 67/100
# 10/10 [==============================] - 1s 75ms/step - loss: 5.4813e-04 - mae: 0.0273
# Epoch 68/100
# 10/10 [==============================] - 1s 75ms/step - loss: 7.2991e-04 - mae: 0.0312
# Epoch 69/100
# 10/10 [==============================] - 1s 76ms/step - loss: 9.1336e-04 - mae: 0.0350
# Epoch 70/100
# 10/10 [==============================] - 1s 76ms/step - loss: 9.4815e-04 - mae: 0.0348
# Epoch 71/100
# 10/10 [==============================] - 1s 78ms/step - loss: 9.1262e-04 - mae: 0.0329
# Epoch 72/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0012 - mae: 0.0368
# Epoch 73/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0023 - mae: 0.0494
# Epoch 74/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0012 - mae: 0.0376
# Epoch 75/100
# 10/10 [==============================] - 1s 74ms/step - loss: 5.5326e-04 - mae: 0.0263
# Epoch 76/100
# 10/10 [==============================] - 1s 74ms/step - loss: 1.2078e-04 - mae: 0.0119
# Epoch 77/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0011 - mae: 0.0417
# Epoch 78/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0091 - mae: 0.1146
# Epoch 79/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0056 - mae: 0.0779
# Epoch 80/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0443 - mae: 0.2095
# Epoch 81/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0844 - mae: 0.2649
# Epoch 82/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.5435 - mae: 1.0175
# Epoch 83/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.3093 - mae: 0.6079
# Epoch 84/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.1248 - mae: 0.3262
# Epoch 85/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1391 - mae: 0.3788
# Epoch 86/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.1666 - mae: 0.4108
# Epoch 87/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.1514 - mae: 0.3782
# Epoch 88/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.1490 - mae: 0.3403
# Epoch 89/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.4738 - mae: 0.9435
# Epoch 90/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.4811 - mae: 0.9056
# Epoch 91/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.6690 - mae: 1.1189
# Epoch 92/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.8199 - mae: 1.3134
# Epoch 93/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.9977 - mae: 1.4586
# Epoch 94/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.8073 - mae: 1.2497
# Epoch 95/100
# 10/10 [==============================] - 1s 76ms/step - loss: 1.3526 - mae: 1.7966
# Epoch 96/100
# 10/10 [==============================] - 1s 78ms/step - loss: 1.6092 - mae: 2.1092
# Epoch 97/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.5722 - mae: 2.0722
# Epoch 98/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.8148 - mae: 2.3134
# Epoch 99/100
# 10/10 [==============================] - 1s 75ms/step - loss: 2.1072 - mae: 2.6070
# Epoch 100/100
# 10/10 [==============================] - 1s 78ms/step - loss: 2.3515 - mae: 2.8515

# %%
plt.semilogx(lr_history.history["lr"], lr_history.history["loss"])
plt.axis([1e-3, 1, 0, .01])
# Out:
# (0.001, 1.0, 0.0, 0.01)

# %% [markdown]
# **Create the runtime model**

# %%
def create_model():
    model = create_uncompiled_model()  #reuse model defined above   
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lambda_4 (Lambda)            (None, None, 1)           0
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, None, 64)          8704
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 64)                24832
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 33,601
# Trainable params: 33,601
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile and train**

# %%
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=tf.keras.optimizers.SGD(momentum=0.2, learning_rate=2e-1 ),
              #optimizer=tf.keras.optimizers.Adam(learning_rate=1.e-1 ),
              metrics=["mae"])  
    
history = model.fit(train_set, epochs=200,verbose=0, validation_data=valid_set)

# %% [markdown]
# **Review results**

# %%
import matplotlib.pyplot as plt

print(history)
print(history.history.keys())

acc = history.history['mae']
val_acc = history.history['val_mae']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#plt.plot(epochs, acc, 'r', label='Training accuracy')
#plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
#plt.title('Accuracy')
#plt.legend(loc=0)
#plt.figure()
#plt.show()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------

#plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.title('MAE')
plt.legend(loc=0)
plt.figure()
plt.show()
# Out:
# <keras.callbacks.History object at 0x0000028991BE5F70>
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %% [markdown]
# **Evaluate the forecast**

# %%
def compute_metrics(true_series, forecast):
    
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %% [markdown]
# **Create windowed dataset for simulation**

# %%
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(32).prefetch(1)
    forecast = model.predict(ds)
    return forecast

# %% [markdown]
# **Run predictions**

# %%
# Compute the forecast for all the series
rnn_forecast = model_forecast(model, G.SERIES, G.WINDOW_SIZE).squeeze()

# Slice the forecast to get only the predictions for the validation set
rnn_forecast = rnn_forecast[G.SPLIT_TIME - G.WINDOW_SIZE:-1]


# Plot the forecast
plt.figure(figsize=(12, 6))
plot_series(time_valid, series_valid)
plot_series(time_valid, rnn_forecast)
#print(np.shape(rnn_forecast))
close=series_valid[-1]*15000.
tomorrow_forecast=(float(rnn_forecast[-1])-float(rnn_forecast[-2]))*15000+close
gain_points=tomorrow_forecast-close
percent=gain_points/close*100.

print("today's close       :",close)
print("tomorrow's forecast : {:.2f}".format(tomorrow_forecast))
print("gain of: {:.2f} points or {:.2f}%\n".format(gain_points,percent))
# Out:
# today's close       : 11183.66016
# tomorrow's forecast : 11211.34
# gain of: 27.68 points or 0.25%

# %%
mse, mae = compute_metrics(series_valid, rnn_forecast)

print(f"mse: {mse:.3f}, mae: {mae:.3f} for forecast")
# Out:
# mse: 0.004, mae: 0.053 for forecast

# %%
all_in=False
wallet=10000.
shares=0
for i in range(1,len(rnn_forecast)):
    if rnn_forecast[i]>series_valid[i-1] and all_in is False:
        print ('buying at {:.0f}'.format(float(series_valid[i-1])*15000))
        all_in =True
        shares=wallet/float(series_valid[i-1])/15000.
        wallet=0
    if rnn_forecast[i]<series_valid[i-1] and all_in is True:
        print ('selling at {:.0f}'.format(float(series_valid[i-1])*15000.))
        all_in = False
        wallet=shares*float(series_valid[i-1])*15000
        shares=0
    close=series_valid[i]*15000
    wealth=wallet+shares*close
    buyhold=10000.*series_valid[i]/series_valid[0]

    print('Day:{:02d} Shares:{:.0f} Close:{:.0f}  Value: ${:.2f}  Cash ${:.2f}  Total wealth is: ${:.2f} vs ${:.2f} for B&H, {:.1f}% better.'.format(i,shares, close, shares*close,wallet, wealth,buyhold,(wealth/buyhold-1)*100))
# Out:
# Day:01 Shares:0 Close:16057  Value: $0.00  Cash $10000.00  Total wealth is: $10000.00 vs $10039.85 for B&H, -0.4% better.
# Day:02 Shares:0 Close:15855  Value: $0.00  Cash $10000.00  Total wealth is: $10000.00 vs $9913.12 for B&H, 0.9% better.
# buying at 15855
# Day:03 Shares:1 Close:15775  Value: $9949.78  Cash $0.00  Total wealth is: $9949.78 vs $9863.34 for B&H, 0.9% better.
# Day:04 Shares:1 Close:15845  Value: $9993.99  Cash $0.00  Total wealth is: $9993.99 vs $9907.16 for B&H, 0.9% better.
# Day:05 Shares:1 Close:15492  Value: $9770.98  Cash $0.00  Total wealth is: $9770.98 vs $9686.10 for B&H, 0.9% better.
# Day:06 Shares:1 Close:15783  Value: $9954.63  Cash $0.00  Total wealth is: $9954.63 vs $9868.15 for B&H, 0.9% better.
# Day:07 Shares:1 Close:15538  Value: $9800.02  Cash $0.00  Total wealth is: $9800.02 vs $9714.88 for B&H, 0.9% better.
# Day:119 Shares:1 Close:11364  Value: $7840.18  Cash $0.00  Total wealth is: $7840.18 vs $7105.44 for B&H, 10.3% better.
# Day:120 Shares:1 Close:11371  Value: $7844.82  Cash $0.00  Total wealth is: $7844.82 vs $7109.64 for B&H, 10.3% better.
# Day:121 Shares:1 Close:11805  Value: $8144.26  Cash $0.00  Total wealth is: $8144.26 vs $7381.03 for B&H, 10.3% better.
# Day:122 Shares:1 Close:11663  Value: $8046.15  Cash $0.00  Total wealth is: $8046.15 vs $7292.11 for B&H, 10.3% better.
# Day:123 Shares:1 Close:11985  Value: $8268.11  Cash $0.00  Total wealth is: $8268.11 vs $7493.27 for B&H, 10.3% better.
# Day:124 Shares:1 Close:11418  Value: $7877.37  Cash $0.00  Total wealth is: $7877.37 vs $7139.15 for B&H, 10.3% better.
# Day:125 Shares:1 Close:11388  Value: $7856.92  Cash $0.00  Total wealth is: $7856.92 vs $7120.61 for B&H, 10.3% better.
# Day:126 Shares:1 Close:11355  Value: $7833.54  Cash $0.00  Total wealth is: $7833.54 vs $7099.43 for B&H, 10.3% better.
# Day:127 Shares:1 Close:11535  Value: $7958.17  Cash $0.00  Total wealth is: $7958.17 vs $7212.38 for B&H, 10.3% better.
# Day:128 Shares:1 Close:11264  Value: $7771.34  Cash $0.00  Total wealth is: $7771.34 vs $7043.05 for B&H, 10.3% better.
# Day:129 Shares:1 Close:11435  Value: $7888.82  Cash $0.00  Total wealth is: $7888.82 vs $7149.52 for B&H, 10.3% better.
# Day:130 Shares:1 Close:11741  Value: $8099.87  Cash $0.00  Total wealth is: $8099.87 vs $7340.79 for B&H, 10.3% better.
# Day:131 Shares:1 Close:12131  Value: $8369.26  Cash $0.00  Total wealth is: $8369.26 vs $7584.94 for B&H, 10.3% better.
# Day:132 Shares:1 Close:12081  Value: $8334.94  Cash $0.00  Total wealth is: $8334.94 vs $7553.84 for B&H, 10.3% better.
# Day:133 Shares:1 Close:11994  Value: $8274.97  Cash $0.00  Total wealth is: $8274.97 vs $7499.49 for B&H, 10.3% better.
# Day:134 Shares:1 Close:12317  Value: $8497.42  Cash $0.00  Total wealth is: $8497.42 vs $7701.09 for B&H, 10.3% better.
# Day:135 Shares:1 Close:12013  Value: $8287.57  Cash $0.00  Total wealth is: $8287.57 vs $7510.91 for B&H, 10.3% better.
# Day:136 Shares:1 Close:12061  Value: $8321.13  Cash $0.00  Total wealth is: $8321.13 vs $7541.32 for B&H, 10.3% better.
# Day:137 Shares:1 Close:12175  Value: $8399.68  Cash $0.00  Total wealth is: $8399.68 vs $7612.51 for B&H, 10.3% better.
# Day:138 Shares:1 Close:12086  Value: $8338.31  Cash $0.00  Total wealth is: $8338.31 vs $7556.89 for B&H, 10.3% better.
# Day:139 Shares:1 Close:11754  Value: $8109.23  Cash $0.00  Total wealth is: $8109.23 vs $7349.28 for B&H, 10.3% better.
# Day:140 Shares:1 Close:11340  Value: $7823.47  Cash $0.00  Total wealth is: $7823.47 vs $7090.30 for B&H, 10.3% better.
