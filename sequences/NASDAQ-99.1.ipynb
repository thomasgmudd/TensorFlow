# %% [markdown]
# ***NASDAQ Predictions***
#
# 99.1% accuracy
#
# dataset is NASDAQ open and volume -  40 year history

# %% [markdown]
# **Imports**

# %%
import csv
import pickle
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from dataclasses import dataclass
from tensorflow.keras.models import Model
from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot
from numpy import shape
import datetime
# %load_ext tensorboard

# %% [markdown]
# **Global Variables**

# %%
MODEL_NUM=4
TRAINING_RATIO = .90
WINDOW_SIZE = 64
BATCH_SIZE = 1024
SHUFFLE_BUFFER = 1000
DATAFILE_CSV = 'd:/data/stocks/nasdaq1984.csv' # from https://finance.yahoo.com/quote/%5EIXIC/history/

# %% [markdown]
# **Describe the data**

# %%
def describe_datafile():
    with open(DATAFILE_CSV, 'r') as mydata:
        print("Header       :  {}".format(mydata.readline()))    
        print("First record :  {}".format(mydata.readline()))
        print("Second record:  {}".format(mydata.readline()))
    
describe_datafile()
# Out:
# Header       :  Date,Open,High,Low,Close,Adj Close,Volume
#
# First record :  10/11/1984,244.199997,244.699997,244.199997,244.699997,244.699997,62860000
#
# Second record:  10/12/1984,245.5,246.199997,245.5,246.199997,246.199997,58860000

# %% [markdown]
# **Parse the .csv data to numpy arrays and data dictionary**

# %%
def norm_close(close):
#     close=np.log(close)
#     close=close-7.5
#     close=close/2
    close=np.divide(close,15000.)
    close=close-.5

    return close    

def denorm_close(close):
#     close=close*2
#     close=close+7.5
#     close=np.exp(close)
    close=close+.5
    close=np.multiply(close,15000)

    return close



def parse_data_from_file(filename):
    
    dates = []
    close = []
    volume= []

    with open(filename) as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        next(reader)
     
        for record in reader:                          # load file records into lists
            dates.append(record[0])
            close.append(float(record[4]))
            volume.append(float(record[6]))
        index=list(range(0,len(dates)))                 # create the index
        
        for datalist in [index, dates, close, volume]:   # turn them into numpy arrays
            datalist=np.array(datalist)
 
        # Log, Normalize and flip
        close=norm_close(close)
        volume=np.divide(volume,1e10)
        #datalist = np.flip(datalist))  

        return index, dates, close, volume
    


index, dates, close, volume = parse_data_from_file(DATAFILE_CSV)

dataarrays= [ index ,  dates ,  close ,  volume]
datanames=['index', 'dates', 'close', 'volume']
datadic={}    

for datum in enumerate(dataarrays):
    print('{:<6} {}'.format(datanames[datum[0]],np.shape(datum[1])))
    datadic[datanames[datum[0]]]=datum[1]

print('\ndatadic {}'.format(str(datadic.keys())))
# Out:
# index  (9611,)
# dates  (9611,)
# close  (9611,)
# volume (9611,)
#
# datadic dict_keys(['index', 'dates', 'close', 'volume'])

# %% [markdown]
# **Plot Processed Data**

# %%
def plot_series(index, series, fignum=0,format="-", start=0, end=None):
            plt.figure(fignum, figsize=(10,4))
            plt.plot(index[start:end], series[start:end], format)
            plt.xlabel("Index")
            plt.ylabel("Series "+str(fignum))
            plt.grid(True)
            plt.title("Series "+str(fignum))

plot_series(index,close, 'close' )
plot_series(index,volume,'volume')

# %% [markdown]
# **Do Train and Validation splits**

# %%
def series_split(series, training_ratio=TRAINING_RATIO):
    first_validation=int(training_ratio*len(series))
    series_train = series[:first_validation]
    series_valid = series[first_validation:]
    
    return series_train, series_valid


# Split the datasets
datadic_train={}
datadic_val={}
print ('Default Training Ratio: {:.0f}%\n'.format(TRAINING_RATIO*100))

for datum in datadic:
    datadic_train[datum], datadic_val[datum] =series_split(datadic[datum])
    print('{:<8}  train shape: {}  validation shape: {}'.format(datum,shape(datadic_train[datum]), shape(datadic_val[datum])))#    datum, np.shape(datadic_train[datum]), np.shape(datadic_val[datum]) )

print ('\nOriginal series is {}'.format(np.shape(index)))
print('datadic_train: ',datadic_train.keys())
print('datadic_val  : ',datadic_val.keys())
# Out:
# Default Training Ratio: 90%
#
# index     train shape: (8649,)  validation shape: (962,)
# dates     train shape: (8649,)  validation shape: (962,)
# close     train shape: (8649,)  validation shape: (962,)
# volume    train shape: (8649,)  validation shape: (962,)
#
# Original series is (9611,)
# datadic_train:  dict_keys(['index', 'dates', 'close', 'volume'])
# datadic_val  :  dict_keys(['index', 'dates', 'close', 'volume'])

# %% [markdown]
# **Create final data arrays**

# %%
data_all=np.stack((datadic['volume'],datadic['close']),axis=1)
data_train, data_val = series_split(data_all)

print('data_all  : ',np.shape(data_all))
print('data_train: ', np.shape(data_train))
print('data_val  : ', np.shape(data_val))


close_train, close_val = series_split(datadic['close'])
vol_train, vol_val = series_split(datadic['volume'])
index_train,index_val = series_split(index)

print('\nclose_train: ',np.shape(close_train))
print(  'vol_train  : ',np.shape(vol_train))
# Out:
# data_all  :  (9611, 2)
# data_train:  (8649, 2)
# data_val  :  (962, 2)
#
# close_train:  (8649,)
# vol_train  :  (8649,)

# %% [markdown]
# ***Create windowed dataset***

# %%
def windowed_dataset_multi(series1, window_size=WINDOW_SIZE, batch_size=BATCH_SIZE, shuffle_buffer=SHUFFLE_BUFFER, shuffle=1, verbose=0):
    
    ds = tf.data.Dataset.from_tensor_slices(series1)
    if verbose==1:
        for elem in ds:
            print('created tensor: ')
            print('   ds elem:', elem)
            print('   ds elem[0]:',elem[0])
            print('   ds elem[1]:',elem[1])
            break
    
    #if shuffle==1: ds = ds.shuffle(shuffle_buffer)  
    
    ds = ds.window(window_size+1, shift=1, drop_remainder=True)  # +1 is the label
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))
    ds = ds.map(lambda w: (w[:-1], w[-1,1]))  # maps inputs and label
     
    if verbose==1:
        print('\nAfter batch map:')
        for elem in ds:
             print('   ds elem:', np.shape(elem))
             print('   ds elem[0][0] :',shape(elem[0]),elem[0][0])
             print('   ds elem[0][-1]:',shape(elem[0]),elem[0][-1])
             print('   ds elem[1]:',shape(elem[1]),elem[1])
             break
        
    ds = ds.batch(batch_size).prefetch(1)
    
    if verbose==1:
        print('\nAfter creating batches:')
        for elem in ds:
            print('   ds elem[0]:',shape(elem[0]))
            print('   ds elem[1]:',shape(elem[1]),elem[1][63],'\n')
            break
    
    return ds

# Apply the transformation to the training set

print('sending data_train: ',shape(data_train), type(data_train)) 
print('   data_train[0,0]',data_train[0,0])
print('   data_train[0,1]',data_train[0,1],'\n')

train_set  = windowed_dataset_multi(data_train, window_size=64, batch_size=BATCH_SIZE, shuffle_buffer=SHUFFLE_BUFFER, verbose=1,shuffle=1)
val_set  = windowed_dataset_multi(data_val, window_size=64, batch_size=BATCH_SIZE, shuffle_buffer=SHUFFLE_BUFFER, shuffle=0)
# Out:
# sending data_train:  (8649, 2) <class 'numpy.ndarray'>
#    data_train[0,0] 0.006286
#    data_train[0,1] -0.48368666686666667
#
# created tensor:
#    ds elem: tf.Tensor([ 0.006286   -0.48368667], shape=(2,), dtype=float64)
#    ds elem[0]: tf.Tensor(0.006286, shape=(), dtype=float64)
#    ds elem[1]: tf.Tensor(-0.48368666686666667, shape=(), dtype=float64)
#
# After batch map:
#    ds elem: (2,)
#    ds elem[0][0] : (64, 2) tf.Tensor([ 0.006286   -0.48368667], shape=(2,), dtype=float64)
#    ds elem[0][-1]: (64, 2) tf.Tensor([ 0.007152   -0.48318667], shape=(2,), dtype=float64)
#    ds elem[1]: () tf.Tensor(-0.48296666666666666, shape=(), dtype=float64)
#
# After creating batches:
#    ds elem[0]: (1024, 64, 2)
#    ds elem[1]: (1024,) tf.Tensor(-0.4812599996, shape=(), dtype=float64)

# %%
for elem in train_set:
    print('last close in window: ',denorm_close(elem[0][-1,-1,1]))  # [inputs][batch, window, volume]
    print('label for next close: ',denorm_close(elem[1][-1]))       # [labels][batch, window, close ]
    print('percent change: {:+3.2}%'.format(float(elem[0][-1,-1,1])/float(elem[1][-1])*100-100))
    print('\n')
    break
# Out:
# last close in window:  399.200012
# label for next close:  401.2999880000001
# percent change: +0.03%

# %% [markdown]
# **Define the model**

# %%
def test_model():

        # inputs
        input_layer=tf.keras.Input(shape=(WINDOW_SIZE,2))  #both
        x=input_layer[:,:,1]       # batch, window, close
        y=input_layer[:,-32:,0]    # batch, window, volume
        w=input_layer[:,-16:,:]    # batch, window, vol&close
        s1=input_layer[:,-1,1]     # batch, last value, close
        
        # close lstms
        x=tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None], name ='addDepthClose')(x)
        x=tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh', name='Close1')(x)
        x=tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh', name='Close2')(x)
        x=tf.keras.layers.LSTM(128, name='Close3')(x)
        x=tf.keras.layers.Dense(128)(x)
        x=tf.keras.layers.Dense(64)(x)
        
        # volume convolutions
        y=tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None],name='addDepthVolume')(y)
        y=tf.keras.layers.Conv1D(filters=16, kernel_size=7, strides=1, padding='same', activation='relu')(y)
        y=tf.keras.layers.Flatten(name='Volume0')(y)
        y=tf.keras.layers.Dense(64, name='Volume1')(y)
        y=tf.keras.layers.Dense(64, name='Volume2')(y)

        # close and volume convolutions
        w=tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None], name='Both0')(w)
        w=tf.keras.layers.Conv2D(filters=16, kernel_size=(3,2), strides=1, padding='same', activation='relu', name='Both1')(w)
        w=tf.math.reduce_max(w,axis=2)
        w=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh', name='Both2'))(w)
        w=tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, activation='tanh'))(w)
        w=tf.keras.layers.Flatten()(w)
        w=tf.keras.layers.Dense(64)(w)
        w=tf.keras.layers.Dense(64)(w)
        
        # skip route
        s1=tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None])(s1)        
        
        # master DNN        
        z=tf.keras.layers.Concatenate(axis=1,)([x,y,w,s1])     
        z=tf.keras.layers.Dense(128)(z)
        z=tf.keras.layers.Dense(64)(z)
        z=tf.keras.layers.Dense(32)(z)
        z=tf.keras.layers.Dense(16)(z)
        z=tf.keras.layers.Concatenate(axis=1,)([z,s1])
        
        # output
        output_layer=tf.keras.layers.Dense(1)(z)       
        model = Model(inputs=input_layer, outputs=output_layer)
    
        return model

# %%
def best_model():  

        # inputs
        input_layer=tf.keras.Input(shape=(WINDOW_SIZE,2))  #both
        x=input_layer[:,:,1]       # batch, window, close
        y=input_layer[:,-32:,0]       # batch, window, volume
        s1=input_layer[:,-1,1]  # batch, last value, close

        # close lstms
        x=tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None])(x)
        x=tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh')(x)
        x=tf.keras.layers.LSTM(128, return_sequences=True, activation='tanh')(x)
        x=tf.keras.layers.LSTM(128, activations='tanh')(x)
        x=tf.keras.layers.Dense(64)(x)
        
        # volume convolutions
        y=tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None])(y)
        y=tf.keras.layers.Conv1D(filters=16, kernel_size=7, strides=1, padding='same', activation='relu')(y)
        y=tf.keras.layers.Dense(64)(y)
        y=tf.keras.layers.Dense(64)(y)
        y=tf.keras.layers.Flatten()(y)

        # skip route
        s1=tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),input_shape=[None])(s1)        
        
        # master DNN
        z=tf.keras.layers.Concatenate(axis=1,)([x,y,s1])     
        z=tf.keras.layers.Dense(128)(z)
        z=tf.keras.layers.Dense(64)(z)
        z=tf.keras.layers.Dense(32)(z)
        z=tf.keras.layers.Dense(16)(z)
        z=tf.keras.layers.Concatenate(axis=1,)([z,s1])
        
        
        # output
        output_layer=tf.keras.layers.Dense(1)(z)       
        model = Model(inputs=input_layer, outputs=output_layer)
    
        return model

# %%
#tuning_model=create_model()
tuning_model=best_model()

tuning_model.summary()
print('predictions returned: ',shape(tuning_model.predict(train_set)))
# Out:
# Model: "model_38"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_41 (InputLayer)           [(None, 64, 2)]      0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_149 (S (None, 64)           0           input_41[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 64, 1)        0           tf.__operators__.getitem_149[0][0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_150 (S (None, 32)           0           input_41[0][0]
# __________________________________________________________________________________________________
# lstm_79 (LSTM)                  (None, 64, 128)      66560       lambda_83[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 32, 1)        0           tf.__operators__.getitem_150[0][0
# __________________________________________________________________________________________________
# lstm_80 (LSTM)                  (None, 64, 128)      131584      lstm_79[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 32, 16)       128         lambda_84[0][0]
# __________________________________________________________________________________________________
# lstm_81 (LSTM)                  (None, 128)          131584      lstm_80[0][0]
# __________________________________________________________________________________________________
# dense_284 (Dense)               (None, 32, 64)       1088        conv1d_38[0][0]
# __________________________________________________________________________________________________
# dense_282 (Dense)               (None, 64)           8256        lstm_81[0][0]
# __________________________________________________________________________________________________
# dense_285 (Dense)               (None, 32, 64)       4160        dense_284[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_151 (S (None,)              0           input_41[0][0]
# __________________________________________________________________________________________________
# dense_283 (Dense)               (None, 32)           2080        dense_282[0][0]
# __________________________________________________________________________________________________
# flatten_54 (Flatten)            (None, 2048)         0           dense_285[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 1)            0           tf.__operators__.getitem_151[0][0
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 2081)         0           dense_283[0][0]
#                                                                  flatten_54[0][0]
#                                                                  lambda_85[0][0]
# __________________________________________________________________________________________________
# dense_286 (Dense)               (None, 128)          266496      concatenate_76[0][0]
# __________________________________________________________________________________________________
# dense_287 (Dense)               (None, 64)           8256        dense_286[0][0]
# __________________________________________________________________________________________________
# dense_288 (Dense)               (None, 32)           2080        dense_287[0][0]
# __________________________________________________________________________________________________
# dense_289 (Dense)               (None, 16)           528         dense_288[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 17)           0           dense_289[0][0]
#                                                                  lambda_85[0][0]
# __________________________________________________________________________________________________
# dense_290 (Dense)               (None, 1)            18          concatenate_77[0][0]
# ==================================================================================================
# Total params: 622,818
# Trainable params: 622,818
# Non-trainable params: 0
# __________________________________________________________________________________________________
# predictions returned:  (8585, 1)

# %% [markdown]
# **Try a range of learning rates**

# %%
def try_learning_rates(model, dataset):
    
    
    lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch / 20))
    stop_callback = tf.keras.callbacks.EarlyStopping(patience=20, monitor='mae', verbose=1, mode='min', restore_best_weights=True)
    callbacks=[lr_schedule, stop_callback]
    #optimizer=tf.keras.optimizers.Adam(learning_rate=5.e-5 )
    optimizer=tf.keras.optimizers.SGD (learning_rate=5.e-5, momentum=.9) 
    
    model.compile(loss=tf.keras.losses.Huber(),
                  optimizer=optimizer, 
                  metrics=["mae"]) 
    
    history = model.fit(train_set, epochs=100, callbacks=callbacks)
    
    return history

# Train in a range of learning rates


tuning_model=create_model() 
lr_history = try_learning_rates(tuning_model,train_set)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 11s 123ms/step - loss: 0.0508 - mae: 0.2885
# Epoch 2/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0380 - mae: 0.2431
# Epoch 3/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0250 - mae: 0.1922
# Epoch 4/100
# 9/9 [==============================] - 1s 122ms/step - loss: 0.0164 - mae: 0.1506
# Epoch 5/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0124 - mae: 0.1292
# Epoch 6/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0105 - mae: 0.1180
# Epoch 7/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0097 - mae: 0.1133
# Epoch 8/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0094 - mae: 0.1109
# Epoch 9/100
# 9/9 [==============================] - 1s 122ms/step - loss: 0.0090 - mae: 0.1086
# Epoch 10/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0090 - mae: 0.1091
# Epoch 11/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0090 - mae: 0.1088
# Epoch 12/100
# 9/9 [==============================] - 1s 123ms/step - loss: 0.0087 - mae: 0.1069
# Epoch 13/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0085 - mae: 0.1059
# Epoch 14/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0084 - mae: 0.1048
# Epoch 15/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0081 - mae: 0.1027
# Epoch 16/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0078 - mae: 0.1011
# Epoch 17/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0075 - mae: 0.0992
# Epoch 18/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0071 - mae: 0.0962
# Epoch 19/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0066 - mae: 0.0932
# Epoch 20/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0064 - mae: 0.0914
# Epoch 21/100
# 9/9 [==============================] - 1s 123ms/step - loss: 0.0059 - mae: 0.0884
# Epoch 22/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0056 - mae: 0.0856
# Epoch 23/100
# 9/9 [==============================] - 1s 120ms/step - loss: 0.0050 - mae: 0.0805
# Epoch 24/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0047 - mae: 0.0786
# Epoch 25/100
# 9/9 [==============================] - 1s 125ms/step - loss: 0.0043 - mae: 0.0758
# Epoch 26/100
# 9/9 [==============================] - 1s 127ms/step - loss: 0.0038 - mae: 0.0701
# Epoch 27/100
# 9/9 [==============================] - 1s 124ms/step - loss: 0.0034 - mae: 0.0663
# Epoch 28/100
# 9/9 [==============================] - 1s 126ms/step - loss: 0.0029 - mae: 0.0620
# Epoch 29/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0025 - mae: 0.0568
# Epoch 30/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0022 - mae: 0.0530
# Epoch 31/100
# 9/9 [==============================] - 1s 121ms/step - loss: 0.0018 - mae: 0.0481
# Epoch 32/100
# 9/9 [==============================] - 1s 123ms/step - loss: 0.0015 - mae: 0.0436
# Epoch 33/100
# 9/9 [==============================] - 1s 124ms/step - loss: 0.0012 - mae: 0.0390
# Epoch 34/100
# 9/9 [==============================] - 1s 121ms/step - loss: 9.8156e-04 - mae: 0.0348
# Epoch 35/100
# 9/9 [==============================] - 1s 121ms/step - loss: 8.4061e-04 - mae: 0.0324
# Epoch 36/100
# 9/9 [==============================] - 1s 122ms/step - loss: 6.8801e-04 - mae: 0.0288
# Epoch 37/100
# 9/9 [==============================] - 1s 121ms/step - loss: 6.3883e-04 - mae: 0.0279
# Epoch 38/100
# 9/9 [==============================] - 1s 121ms/step - loss: 5.8766e-04 - mae: 0.0267
# Epoch 39/100
# 9/9 [==============================] - 1s 121ms/step - loss: 6.0405e-04 - mae: 0.0271
# Epoch 40/100
# 9/9 [==============================] - 1s 121ms/step - loss: 6.0999e-04 - mae: 0.0274
# Epoch 41/100
# 9/9 [==============================] - 1s 121ms/step - loss: 6.0177e-04 - mae: 0.0270
# Epoch 42/100
# 9/9 [==============================] - 1s 121ms/step - loss: 5.5836e-04 - mae: 0.0262
# Epoch 43/100
# 9/9 [==============================] - 1s 122ms/step - loss: 5.2826e-04 - mae: 0.0255
# Epoch 44/100
# 9/9 [==============================] - 1s 122ms/step - loss: 4.9939e-04 - mae: 0.0250
# Epoch 45/100
# 9/9 [==============================] - 1s 121ms/step - loss: 4.7828e-04 - mae: 0.0244
# Epoch 46/100
# 9/9 [==============================] - 1s 121ms/step - loss: 4.4029e-04 - mae: 0.0233
# Epoch 47/100
# 9/9 [==============================] - 1s 129ms/step - loss: 4.2999e-04 - mae: 0.0232
# Epoch 48/100
# 9/9 [==============================] - 1s 132ms/step - loss: 3.7297e-04 - mae: 0.0215
# Epoch 49/100
# 9/9 [==============================] - 1s 127ms/step - loss: 3.5471e-04 - mae: 0.0209
# Epoch 50/100
# 9/9 [==============================] - 1s 131ms/step - loss: 3.0115e-04 - mae: 0.0191
# Epoch 51/100
# 9/9 [==============================] - 1s 130ms/step - loss: 2.9587e-04 - mae: 0.0190
# Epoch 52/100
# 9/9 [==============================] - 1s 130ms/step - loss: 2.6319e-04 - mae: 0.0179
# Epoch 53/100
# 9/9 [==============================] - 1s 131ms/step - loss: 2.7751e-04 - mae: 0.0184
# Epoch 54/100
# 9/9 [==============================] - 1s 132ms/step - loss: 2.5737e-04 - mae: 0.0175
# Epoch 55/100
# 9/9 [==============================] - 1s 131ms/step - loss: 2.3733e-04 - mae: 0.0170
# Epoch 56/100
# 9/9 [==============================] - 1s 133ms/step - loss: 2.4490e-04 - mae: 0.0175
# Epoch 57/100
# 9/9 [==============================] - 1s 130ms/step - loss: 6.2623e-04 - mae: 0.0291
# Epoch 58/100
# 9/9 [==============================] - 1s 132ms/step - loss: 0.0013 - mae: 0.0426
# Epoch 59/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.0033 - mae: 0.0667
# Epoch 60/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.0063 - mae: 0.1040
# Epoch 61/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0267 - mae: 0.2051
# Epoch 62/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0185 - mae: 0.1655
# Epoch 63/100
# 9/9 [==============================] - 1s 133ms/step - loss: 0.0263 - mae: 0.2077
# Epoch 64/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.0213 - mae: 0.1736
# Epoch 65/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0166 - mae: 0.1515
# Epoch 66/100
# 9/9 [==============================] - 1s 134ms/step - loss: 0.0158 - mae: 0.1442
# Epoch 67/100
# 9/9 [==============================] - 1s 130ms/step - loss: 0.0151 - mae: 0.1460
# Epoch 68/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0117 - mae: 0.1286
# Epoch 69/100
# 9/9 [==============================] - 1s 135ms/step - loss: 0.0057 - mae: 0.0896
# Epoch 70/100
# 9/9 [==============================] - 1s 132ms/step - loss: 0.0079 - mae: 0.1045
# Epoch 71/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0094 - mae: 0.1202
# Epoch 72/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0048 - mae: 0.0839
# Epoch 73/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0055 - mae: 0.0930
# Epoch 74/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0063 - mae: 0.0952
# Epoch 75/100
# 9/9 [==============================] - 1s 131ms/step - loss: 0.0045 - mae: 0.0883
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping

# %% [markdown]
# **Review results and set optimized learning rate**

# %%
LEARNING_RATE=1e-6               ##  This sets learning rate for the model below  ##
print(lr_history.history.keys())
plt.semilogx(lr_history.history["lr"], lr_history.history["mae"])
plt.axis([1e-4,1, 0, .2])
plt.axvline(x = LEARNING_RATE, color = 'r' ,linestyle='dotted')
plt.show()
# Out:
# dict_keys(['loss', 'mae', 'lr'])

# %% [markdown]
# **Create the training model**

# %%
#model = create_model()
model=best_model()
print('predictions returned: ',shape(tuning_model.predict(train_set)))
# Out:
# predictions returned:  (8585, 1)

# %% [markdown]
# **Review model**

# %%
plot_model(model , to_file="nasdaq.png" , show_shapes= True , show_layer_names=True)
#model.summary()

# %% [markdown]
# **Save and load model**

# %%
# Save model to HDF5 file

#model.save('modelx',save_format="h5")
#model.save_weights('weights.x')
#model.load_weights('decent')

# %% [markdown]
# **Callbacks, optimize, compile**

# %%
#callbacks
tensorboard_callback = tf.keras.callbacks.TensorBoard('tensorboard')
stop_callback = tf.keras.callbacks.EarlyStopping(patience=200, monitor='val_mae', verbose=1, mode='min', restore_best_weights=True)
lr_callback=tf.keras.callbacks.ReduceLROnPlateau(monitor='val_mae', factor=0.95, verbose=1, patience=100, min_delta=.000001, min_lr=1e-6),
callbacks=[lr_callback, stop_callback]

#optimize & compile
optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE )
#optimizer=tf.keras.optimizers.SGD (learning_rate=LEARNING_RATE, momentum=.9) 

#model.compile(loss=tf.keras.losses.Huber(), optimizer=optimizer, metrics=["mae"]) 
model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer=optimizer, metrics=["mae"])

# %% [markdown]
# **Train**

# %%
#train
history =  model.fit(train_set, epochs=5000, callbacks=callbacks, verbose=1, validation_data=val_set)
# Out:
# Epoch 1/5000
# 9/9 [==============================] - 6s 224ms/step - loss: 6.1763e-06 - mae: 0.0015 - val_loss: 1.6473e-04 - val_mae: 0.0094
# Epoch 2/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.1333e-06 - mae: 0.0015 - val_loss: 1.6461e-04 - val_mae: 0.0094
# Epoch 3/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.1174e-06 - mae: 0.0014 - val_loss: 1.6455e-04 - val_mae: 0.0094
# Epoch 4/5000
# 9/9 [==============================] - 1s 110ms/step - loss: 6.1073e-06 - mae: 0.0014 - val_loss: 1.6454e-04 - val_mae: 0.0094
# Epoch 5/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.1011e-06 - mae: 0.0014 - val_loss: 1.6457e-04 - val_mae: 0.0094
# Epoch 6/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0951e-06 - mae: 0.0014 - val_loss: 1.6466e-04 - val_mae: 0.0095
# Epoch 7/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0887e-06 - mae: 0.0014 - val_loss: 1.6478e-04 - val_mae: 0.0095
# Epoch 8/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0831e-06 - mae: 0.0014 - val_loss: 1.6494e-04 - val_mae: 0.0095
# Epoch 9/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0788e-06 - mae: 0.0014 - val_loss: 1.6512e-04 - val_mae: 0.0095
# Epoch 10/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0754e-06 - mae: 0.0014 - val_loss: 1.6531e-04 - val_mae: 0.0095
# Epoch 11/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0729e-06 - mae: 0.0014 - val_loss: 1.6551e-04 - val_mae: 0.0095
# Epoch 12/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0708e-06 - mae: 0.0014 - val_loss: 1.6570e-04 - val_mae: 0.0095
# Epoch 13/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0692e-06 - mae: 0.0014 - val_loss: 1.6588e-04 - val_mae: 0.0096
# Epoch 14/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0679e-06 - mae: 0.0014 - val_loss: 1.6606e-04 - val_mae: 0.0096
# Epoch 15/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0669e-06 - mae: 0.0014 - val_loss: 1.6622e-04 - val_mae: 0.0096
# Epoch 16/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0662e-06 - mae: 0.0014 - val_loss: 1.6636e-04 - val_mae: 0.0096
# Epoch 17/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0656e-06 - mae: 0.0014 - val_loss: 1.6649e-04 - val_mae: 0.0096
# Epoch 18/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0651e-06 - mae: 0.0014 - val_loss: 1.6661e-04 - val_mae: 0.0096
# Epoch 19/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0648e-06 - mae: 0.0014 - val_loss: 1.6671e-04 - val_mae: 0.0096
# Epoch 20/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0645e-06 - mae: 0.0014 - val_loss: 1.6680e-04 - val_mae: 0.0096
# Epoch 21/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0642e-06 - mae: 0.0014 - val_loss: 1.6688e-04 - val_mae: 0.0096
# Epoch 22/5000
# 9/9 [==============================] - 1s 121ms/step - loss: 6.0640e-06 - mae: 0.0014 - val_loss: 1.6695e-04 - val_mae: 0.0096
# Epoch 23/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0638e-06 - mae: 0.0014 - val_loss: 1.6702e-04 - val_mae: 0.0096
# Epoch 24/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0637e-06 - mae: 0.0014 - val_loss: 1.6708e-04 - val_mae: 0.0096
# Epoch 25/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0635e-06 - mae: 0.0014 - val_loss: 1.6713e-04 - val_mae: 0.0096
# Epoch 26/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0634e-06 - mae: 0.0014 - val_loss: 1.6717e-04 - val_mae: 0.0096
# Epoch 27/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0633e-06 - mae: 0.0014 - val_loss: 1.6722e-04 - val_mae: 0.0096
# Epoch 28/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0632e-06 - mae: 0.0014 - val_loss: 1.6726e-04 - val_mae: 0.0096
# Epoch 29/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0631e-06 - mae: 0.0014 - val_loss: 1.6729e-04 - val_mae: 0.0096
# Epoch 30/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0631e-06 - mae: 0.0014 - val_loss: 1.6733e-04 - val_mae: 0.0096
# Epoch 31/5000
# 9/9 [==============================] - 1s 121ms/step - loss: 6.0630e-06 - mae: 0.0014 - val_loss: 1.6736e-04 - val_mae: 0.0096
# Epoch 32/5000
# 9/9 [==============================] - 1s 121ms/step - loss: 6.0629e-06 - mae: 0.0014 - val_loss: 1.6738e-04 - val_mae: 0.0096
# Epoch 33/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0629e-06 - mae: 0.0014 - val_loss: 1.6741e-04 - val_mae: 0.0096
# Epoch 34/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0628e-06 - mae: 0.0014 - val_loss: 1.6744e-04 - val_mae: 0.0096
# Epoch 35/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0628e-06 - mae: 0.0014 - val_loss: 1.6746e-04 - val_mae: 0.0096
# Epoch 36/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0627e-06 - mae: 0.0014 - val_loss: 1.6748e-04 - val_mae: 0.0096
# Epoch 37/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0627e-06 - mae: 0.0014 - val_loss: 1.6750e-04 - val_mae: 0.0096
# Epoch 38/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0626e-06 - mae: 0.0014 - val_loss: 1.6752e-04 - val_mae: 0.0096
# Epoch 39/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0626e-06 - mae: 0.0014 - val_loss: 1.6754e-04 - val_mae: 0.0096
# Epoch 40/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0626e-06 - mae: 0.0014 - val_loss: 1.6756e-04 - val_mae: 0.0096
# Epoch 41/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0625e-06 - mae: 0.0014 - val_loss: 1.6757e-04 - val_mae: 0.0096
# Epoch 42/5000
# 9/9 [==============================] - 1s 110ms/step - loss: 6.0625e-06 - mae: 0.0014 - val_loss: 1.6758e-04 - val_mae: 0.0096
# Epoch 43/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0625e-06 - mae: 0.0014 - val_loss: 1.6760e-04 - val_mae: 0.0096
# Epoch 44/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0624e-06 - mae: 0.0014 - val_loss: 1.6761e-04 - val_mae: 0.0096
# Epoch 45/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0624e-06 - mae: 0.0014 - val_loss: 1.6762e-04 - val_mae: 0.0096
# Epoch 46/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0624e-06 - mae: 0.0014 - val_loss: 1.6763e-04 - val_mae: 0.0096
# Epoch 47/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0623e-06 - mae: 0.0014 - val_loss: 1.6764e-04 - val_mae: 0.0096
# Epoch 48/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0623e-06 - mae: 0.0014 - val_loss: 1.6764e-04 - val_mae: 0.0096
# Epoch 49/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0623e-06 - mae: 0.0014 - val_loss: 1.6765e-04 - val_mae: 0.0096
# Epoch 50/5000
# 9/9 [==============================] - 1s 125ms/step - loss: 6.0622e-06 - mae: 0.0014 - val_loss: 1.6765e-04 - val_mae: 0.0096
# Epoch 51/5000
# 9/9 [==============================] - 1s 125ms/step - loss: 6.0622e-06 - mae: 0.0014 - val_loss: 1.6766e-04 - val_mae: 0.0096
# Epoch 52/5000
# 9/9 [==============================] - 1s 124ms/step - loss: 6.0622e-06 - mae: 0.0014 - val_loss: 1.6766e-04 - val_mae: 0.0096
# Epoch 53/5000
# 9/9 [==============================] - 1s 124ms/step - loss: 6.0621e-06 - mae: 0.0014 - val_loss: 1.6766e-04 - val_mae: 0.0096
# Epoch 54/5000
# 9/9 [==============================] - 1s 123ms/step - loss: 6.0621e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 55/5000
# 9/9 [==============================] - 1s 122ms/step - loss: 6.0621e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 56/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0620e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 57/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0620e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 58/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0620e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 59/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0619e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 60/5000
# 9/9 [==============================] - 1s 122ms/step - loss: 6.0619e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 61/5000
# 9/9 [==============================] - 1s 125ms/step - loss: 6.0619e-06 - mae: 0.0014 - val_loss: 1.6767e-04 - val_mae: 0.0096
# Epoch 62/5000
# 9/9 [==============================] - 1s 125ms/step - loss: 6.0618e-06 - mae: 0.0014 - val_loss: 1.6766e-04 - val_mae: 0.0096
# Epoch 63/5000
# 9/9 [==============================] - 1s 123ms/step - loss: 6.0618e-06 - mae: 0.0014 - val_loss: 1.6766e-04 - val_mae: 0.0096
# Epoch 64/5000
# 9/9 [==============================] - 1s 124ms/step - loss: 6.0618e-06 - mae: 0.0014 - val_loss: 1.6766e-04 - val_mae: 0.0096
# Epoch 65/5000
# 9/9 [==============================] - 1s 125ms/step - loss: 6.0617e-06 - mae: 0.0014 - val_loss: 1.6765e-04 - val_mae: 0.0096
# Epoch 66/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0617e-06 - mae: 0.0014 - val_loss: 1.6765e-04 - val_mae: 0.0096
# Epoch 67/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0616e-06 - mae: 0.0014 - val_loss: 1.6765e-04 - val_mae: 0.0096
# Epoch 68/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0616e-06 - mae: 0.0014 - val_loss: 1.6764e-04 - val_mae: 0.0096
# Epoch 69/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0616e-06 - mae: 0.0014 - val_loss: 1.6764e-04 - val_mae: 0.0096
# Epoch 70/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0615e-06 - mae: 0.0014 - val_loss: 1.6763e-04 - val_mae: 0.0096
# Epoch 71/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0615e-06 - mae: 0.0014 - val_loss: 1.6763e-04 - val_mae: 0.0096
# Epoch 72/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0614e-06 - mae: 0.0014 - val_loss: 1.6762e-04 - val_mae: 0.0096
# Epoch 73/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0614e-06 - mae: 0.0014 - val_loss: 1.6762e-04 - val_mae: 0.0096
# Epoch 74/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0613e-06 - mae: 0.0014 - val_loss: 1.6761e-04 - val_mae: 0.0096
# Epoch 75/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0613e-06 - mae: 0.0014 - val_loss: 1.6761e-04 - val_mae: 0.0096
# Epoch 76/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0612e-06 - mae: 0.0014 - val_loss: 1.6760e-04 - val_mae: 0.0096
# Epoch 77/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0612e-06 - mae: 0.0014 - val_loss: 1.6759e-04 - val_mae: 0.0096
# Epoch 78/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0611e-06 - mae: 0.0014 - val_loss: 1.6759e-04 - val_mae: 0.0096
# Epoch 79/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0611e-06 - mae: 0.0014 - val_loss: 1.6758e-04 - val_mae: 0.0096
# Epoch 80/5000
# 9/9 [==============================] - 1s 118ms/step - loss: 6.0610e-06 - mae: 0.0014 - val_loss: 1.6757e-04 - val_mae: 0.0096
# Epoch 81/5000
# 9/9 [==============================] - 1s 120ms/step - loss: 6.0610e-06 - mae: 0.0014 - val_loss: 1.6757e-04 - val_mae: 0.0096
# Epoch 82/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0610e-06 - mae: 0.0014 - val_loss: 1.6756e-04 - val_mae: 0.0096
# Epoch 83/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0609e-06 - mae: 0.0014 - val_loss: 1.6755e-04 - val_mae: 0.0096
# Epoch 84/5000
# 9/9 [==============================] - 1s 119ms/step - loss: 6.0608e-06 - mae: 0.0014 - val_loss: 1.6755e-04 - val_mae: 0.0096
# Epoch 85/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0608e-06 - mae: 0.0014 - val_loss: 1.6754e-04 - val_mae: 0.0096
# Epoch 86/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0607e-06 - mae: 0.0014 - val_loss: 1.6753e-04 - val_mae: 0.0096
# Epoch 87/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0607e-06 - mae: 0.0014 - val_loss: 1.6753e-04 - val_mae: 0.0096
# Epoch 88/5000
# 9/9 [==============================] - 1s 118ms/step - loss: 6.0606e-06 - mae: 0.0014 - val_loss: 1.6752e-04 - val_mae: 0.0096
# Epoch 89/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0606e-06 - mae: 0.0014 - val_loss: 1.6751e-04 - val_mae: 0.0096
# Epoch 90/5000
# 9/9 [==============================] - 1s 119ms/step - loss: 6.0605e-06 - mae: 0.0014 - val_loss: 1.6751e-04 - val_mae: 0.0096
# Epoch 91/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0605e-06 - mae: 0.0014 - val_loss: 1.6750e-04 - val_mae: 0.0096
# Epoch 92/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0604e-06 - mae: 0.0014 - val_loss: 1.6749e-04 - val_mae: 0.0096
# Epoch 93/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0604e-06 - mae: 0.0014 - val_loss: 1.6748e-04 - val_mae: 0.0096
# Epoch 94/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0603e-06 - mae: 0.0014 - val_loss: 1.6748e-04 - val_mae: 0.0096
# Epoch 95/5000
# 9/9 [==============================] - 1s 118ms/step - loss: 6.0603e-06 - mae: 0.0014 - val_loss: 1.6747e-04 - val_mae: 0.0096
# Epoch 96/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0602e-06 - mae: 0.0014 - val_loss: 1.6746e-04 - val_mae: 0.0096
# Epoch 97/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0602e-06 - mae: 0.0014 - val_loss: 1.6746e-04 - val_mae: 0.0096
# Epoch 98/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0601e-06 - mae: 0.0014 - val_loss: 1.6745e-04 - val_mae: 0.0096
# Epoch 99/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0601e-06 - mae: 0.0014 - val_loss: 1.6744e-04 - val_mae: 0.0096
# Epoch 100/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0600e-06 - mae: 0.0014 - val_loss: 1.6744e-04 - val_mae: 0.0096
# Epoch 101/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0599e-06 - mae: 0.0014 - val_loss: 1.6743e-04 - val_mae: 0.0096
# Epoch 102/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0599e-06 - mae: 0.0014 - val_loss: 1.6742e-04 - val_mae: 0.0096
# Epoch 103/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0598e-06 - mae: 0.0014 - val_loss: 1.6741e-04 - val_mae: 0.0096
# Epoch 104/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0598e-06 - mae: 0.0014 - val_loss: 1.6741e-04 - val_mae: 0.0096
# Epoch 105/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0597e-06 - mae: 0.0014 - val_loss: 1.6740e-04 - val_mae: 0.0096
# Epoch 106/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0597e-06 - mae: 0.0014 - val_loss: 1.6739e-04 - val_mae: 0.0096
# Epoch 107/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0596e-06 - mae: 0.0014 - val_loss: 1.6739e-04 - val_mae: 0.0096
# Epoch 108/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0596e-06 - mae: 0.0014 - val_loss: 1.6738e-04 - val_mae: 0.0096
# Epoch 109/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0595e-06 - mae: 0.0014 - val_loss: 1.6737e-04 - val_mae: 0.0096
# Epoch 110/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0594e-06 - mae: 0.0014 - val_loss: 1.6737e-04 - val_mae: 0.0096
# Epoch 111/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0594e-06 - mae: 0.0014 - val_loss: 1.6736e-04 - val_mae: 0.0096
# Epoch 112/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0593e-06 - mae: 0.0014 - val_loss: 1.6735e-04 - val_mae: 0.0096
# Epoch 113/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0593e-06 - mae: 0.0014 - val_loss: 1.6735e-04 - val_mae: 0.0096
# Epoch 114/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0592e-06 - mae: 0.0014 - val_loss: 1.6734e-04 - val_mae: 0.0096
# Epoch 115/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0592e-06 - mae: 0.0014 - val_loss: 1.6733e-04 - val_mae: 0.0096
# Epoch 116/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0591e-06 - mae: 0.0014 - val_loss: 1.6733e-04 - val_mae: 0.0096
# Epoch 117/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0591e-06 - mae: 0.0014 - val_loss: 1.6732e-04 - val_mae: 0.0096
# Epoch 118/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0590e-06 - mae: 0.0014 - val_loss: 1.6732e-04 - val_mae: 0.0096
# Epoch 119/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0589e-06 - mae: 0.0014 - val_loss: 1.6731e-04 - val_mae: 0.0096
# Epoch 120/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0589e-06 - mae: 0.0014 - val_loss: 1.6730e-04 - val_mae: 0.0096
# Epoch 121/5000
# 9/9 [==============================] - 1s 120ms/step - loss: 6.0588e-06 - mae: 0.0014 - val_loss: 1.6730e-04 - val_mae: 0.0096
# Epoch 122/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0588e-06 - mae: 0.0014 - val_loss: 1.6729e-04 - val_mae: 0.0096
# Epoch 123/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0587e-06 - mae: 0.0014 - val_loss: 1.6729e-04 - val_mae: 0.0096
# Epoch 124/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0587e-06 - mae: 0.0014 - val_loss: 1.6728e-04 - val_mae: 0.0096
# Epoch 125/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0586e-06 - mae: 0.0014 - val_loss: 1.6727e-04 - val_mae: 0.0096
# Epoch 126/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0585e-06 - mae: 0.0014 - val_loss: 1.6727e-04 - val_mae: 0.0096
# Epoch 127/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0585e-06 - mae: 0.0014 - val_loss: 1.6726e-04 - val_mae: 0.0096
# Epoch 128/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0584e-06 - mae: 0.0014 - val_loss: 1.6726e-04 - val_mae: 0.0096
# Epoch 129/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0584e-06 - mae: 0.0014 - val_loss: 1.6725e-04 - val_mae: 0.0096
# Epoch 130/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0583e-06 - mae: 0.0014 - val_loss: 1.6724e-04 - val_mae: 0.0096
# Epoch 131/5000
# 9/9 [==============================] - 1s 119ms/step - loss: 6.0583e-06 - mae: 0.0014 - val_loss: 1.6724e-04 - val_mae: 0.0096
# Epoch 132/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0582e-06 - mae: 0.0014 - val_loss: 1.6723e-04 - val_mae: 0.0096
# Epoch 133/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0582e-06 - mae: 0.0014 - val_loss: 1.6723e-04 - val_mae: 0.0096
# Epoch 134/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0581e-06 - mae: 0.0014 - val_loss: 1.6722e-04 - val_mae: 0.0096
# Epoch 135/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0580e-06 - mae: 0.0014 - val_loss: 1.6722e-04 - val_mae: 0.0096
# Epoch 136/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0580e-06 - mae: 0.0014 - val_loss: 1.6721e-04 - val_mae: 0.0096
# Epoch 137/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0579e-06 - mae: 0.0014 - val_loss: 1.6721e-04 - val_mae: 0.0096
# Epoch 138/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0579e-06 - mae: 0.0014 - val_loss: 1.6720e-04 - val_mae: 0.0096
# Epoch 139/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0578e-06 - mae: 0.0014 - val_loss: 1.6720e-04 - val_mae: 0.0096
# Epoch 140/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0578e-06 - mae: 0.0014 - val_loss: 1.6719e-04 - val_mae: 0.0096
# Epoch 141/5000
# 9/9 [==============================] - 1s 116ms/step - loss: 6.0577e-06 - mae: 0.0014 - val_loss: 1.6719e-04 - val_mae: 0.0096
# Epoch 142/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0576e-06 - mae: 0.0014 - val_loss: 1.6718e-04 - val_mae: 0.0096
# Epoch 143/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0576e-06 - mae: 0.0014 - val_loss: 1.6717e-04 - val_mae: 0.0096
# Epoch 144/5000
# 9/9 [==============================] - 1s 118ms/step - loss: 6.0575e-06 - mae: 0.0014 - val_loss: 1.6717e-04 - val_mae: 0.0096
# Epoch 145/5000
# 9/9 [==============================] - 1s 115ms/step - loss: 6.0575e-06 - mae: 0.0014 - val_loss: 1.6716e-04 - val_mae: 0.0096
# Epoch 146/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0574e-06 - mae: 0.0014 - val_loss: 1.6716e-04 - val_mae: 0.0096
# Epoch 147/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0574e-06 - mae: 0.0014 - val_loss: 1.6715e-04 - val_mae: 0.0096
# Epoch 148/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0573e-06 - mae: 0.0014 - val_loss: 1.6715e-04 - val_mae: 0.0096
# Epoch 149/5000
# 9/9 [==============================] - 1s 120ms/step - loss: 6.0573e-06 - mae: 0.0014 - val_loss: 1.6715e-04 - val_mae: 0.0096
# Epoch 150/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0572e-06 - mae: 0.0014 - val_loss: 1.6714e-04 - val_mae: 0.0096
# Epoch 151/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0571e-06 - mae: 0.0014 - val_loss: 1.6714e-04 - val_mae: 0.0096
# Epoch 152/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0571e-06 - mae: 0.0014 - val_loss: 1.6713e-04 - val_mae: 0.0096
# Epoch 153/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0570e-06 - mae: 0.0014 - val_loss: 1.6713e-04 - val_mae: 0.0096
# Epoch 154/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0570e-06 - mae: 0.0014 - val_loss: 1.6712e-04 - val_mae: 0.0096
# Epoch 155/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0569e-06 - mae: 0.0014 - val_loss: 1.6712e-04 - val_mae: 0.0096
# Epoch 156/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0569e-06 - mae: 0.0014 - val_loss: 1.6711e-04 - val_mae: 0.0096
# Epoch 157/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0568e-06 - mae: 0.0014 - val_loss: 1.6711e-04 - val_mae: 0.0096
# Epoch 158/5000
# 9/9 [==============================] - 1s 118ms/step - loss: 6.0567e-06 - mae: 0.0014 - val_loss: 1.6710e-04 - val_mae: 0.0096
# Epoch 159/5000
# 9/9 [==============================] - 1s 119ms/step - loss: 6.0567e-06 - mae: 0.0014 - val_loss: 1.6710e-04 - val_mae: 0.0096
# Epoch 160/5000
# 9/9 [==============================] - 1s 117ms/step - loss: 6.0566e-06 - mae: 0.0014 - val_loss: 1.6709e-04 - val_mae: 0.0096
# Epoch 161/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0566e-06 - mae: 0.0014 - val_loss: 1.6709e-04 - val_mae: 0.0096
# Epoch 162/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0565e-06 - mae: 0.0014 - val_loss: 1.6709e-04 - val_mae: 0.0096
# Epoch 163/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0565e-06 - mae: 0.0014 - val_loss: 1.6708e-04 - val_mae: 0.0096
# Epoch 164/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0564e-06 - mae: 0.0014 - val_loss: 1.6708e-04 - val_mae: 0.0096
# Epoch 165/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0563e-06 - mae: 0.0014 - val_loss: 1.6707e-04 - val_mae: 0.0096
# Epoch 166/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0563e-06 - mae: 0.0014 - val_loss: 1.6707e-04 - val_mae: 0.0096
# Epoch 167/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0562e-06 - mae: 0.0014 - val_loss: 1.6707e-04 - val_mae: 0.0096
# Epoch 168/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0562e-06 - mae: 0.0014 - val_loss: 1.6706e-04 - val_mae: 0.0096
# Epoch 169/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0561e-06 - mae: 0.0014 - val_loss: 1.6706e-04 - val_mae: 0.0096
# Epoch 170/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0561e-06 - mae: 0.0014 - val_loss: 1.6706e-04 - val_mae: 0.0096
# Epoch 171/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0560e-06 - mae: 0.0014 - val_loss: 1.6705e-04 - val_mae: 0.0096
# Epoch 172/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0559e-06 - mae: 0.0014 - val_loss: 1.6705e-04 - val_mae: 0.0096
# Epoch 173/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0559e-06 - mae: 0.0014 - val_loss: 1.6705e-04 - val_mae: 0.0096
# Epoch 174/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0558e-06 - mae: 0.0014 - val_loss: 1.6704e-04 - val_mae: 0.0096
# Epoch 175/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0558e-06 - mae: 0.0014 - val_loss: 1.6704e-04 - val_mae: 0.0096
# Epoch 176/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0557e-06 - mae: 0.0014 - val_loss: 1.6704e-04 - val_mae: 0.0096
# Epoch 177/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0557e-06 - mae: 0.0014 - val_loss: 1.6703e-04 - val_mae: 0.0096
# Epoch 178/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0556e-06 - mae: 0.0014 - val_loss: 1.6703e-04 - val_mae: 0.0096
# Epoch 179/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0556e-06 - mae: 0.0014 - val_loss: 1.6703e-04 - val_mae: 0.0096
# Epoch 180/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0555e-06 - mae: 0.0014 - val_loss: 1.6702e-04 - val_mae: 0.0096
# Epoch 181/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0554e-06 - mae: 0.0014 - val_loss: 1.6702e-04 - val_mae: 0.0096
# Epoch 182/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0554e-06 - mae: 0.0014 - val_loss: 1.6702e-04 - val_mae: 0.0096
# Epoch 183/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0553e-06 - mae: 0.0014 - val_loss: 1.6701e-04 - val_mae: 0.0096
# Epoch 184/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0553e-06 - mae: 0.0014 - val_loss: 1.6701e-04 - val_mae: 0.0096
# Epoch 185/5000
# 9/9 [==============================] - 1s 114ms/step - loss: 6.0552e-06 - mae: 0.0014 - val_loss: 1.6701e-04 - val_mae: 0.0096
# Epoch 186/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0552e-06 - mae: 0.0014 - val_loss: 1.6700e-04 - val_mae: 0.0096
# Epoch 187/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0551e-06 - mae: 0.0014 - val_loss: 1.6700e-04 - val_mae: 0.0096
# Epoch 188/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0551e-06 - mae: 0.0014 - val_loss: 1.6700e-04 - val_mae: 0.0096
# Epoch 189/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0550e-06 - mae: 0.0014 - val_loss: 1.6699e-04 - val_mae: 0.0096
# Epoch 190/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0549e-06 - mae: 0.0014 - val_loss: 1.6699e-04 - val_mae: 0.0096
# Epoch 191/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0549e-06 - mae: 0.0014 - val_loss: 1.6699e-04 - val_mae: 0.0096
# Epoch 192/5000
# 9/9 [==============================] - 1s 113ms/step - loss: 6.0548e-06 - mae: 0.0014 - val_loss: 1.6699e-04 - val_mae: 0.0096
# Epoch 193/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0548e-06 - mae: 0.0014 - val_loss: 1.6698e-04 - val_mae: 0.0096
# Epoch 194/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0547e-06 - mae: 0.0014 - val_loss: 1.6698e-04 - val_mae: 0.0096
# Epoch 195/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0547e-06 - mae: 0.0014 - val_loss: 1.6698e-04 - val_mae: 0.0096
# Epoch 196/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0546e-06 - mae: 0.0014 - val_loss: 1.6698e-04 - val_mae: 0.0096
# Epoch 197/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0545e-06 - mae: 0.0014 - val_loss: 1.6697e-04 - val_mae: 0.0096
# Epoch 198/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0545e-06 - mae: 0.0014 - val_loss: 1.6697e-04 - val_mae: 0.0096
# Epoch 199/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0544e-06 - mae: 0.0014 - val_loss: 1.6697e-04 - val_mae: 0.0096
# Epoch 200/5000
# 9/9 [==============================] - 1s 112ms/step - loss: 6.0544e-06 - mae: 0.0014 - val_loss: 1.6696e-04 - val_mae: 0.0096
# Epoch 201/5000
# 9/9 [==============================] - 1s 111ms/step - loss: 6.0543e-06 - mae: 0.0014 - val_loss: 1.6696e-04 - val_mae: 0.0096
# Restoring model weights from the end of the best epoch.
# Epoch 00201: early stopping

# %% [markdown]
# **Review training results**

# %%
print("History: {}".format(history.history.keys()))

acc = history.history['mae']
val_acc = history.history['val_mae']
loss = history.history['loss']
val_loss = history.history['val_loss']
mae = history.history['mae']
val_mae = history.history['val_mae']
epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, mae, 'r', label="Training MAE")
plt.plot(epochs, val_mae, 'b', label="Validation MAE")
plt.title('MAE')
plt.legend(loc=0)
plt.show()
model.evaluate(train_set)
model.evaluate(val_set)
# Out:
# History: dict_keys(['loss', 'mae', 'val_loss', 'val_mae', 'lr'])
# 9/9 [==============================] - 1s 50ms/step - loss: 6.4988e-06 - mae: 0.0017
# 1/1 [==============================] - 0s 134ms/step - loss: 1.6423e-04 - mae: 0.0094
# [0.00016423323540948331, 0.009404840879142284]

# %% [markdown]
# **Evaluate the forecast**

# %% [markdown]
# **Run predictions**

# %%
# Compute the forecast for validation
forecast = model.predict(val_set).squeeze()

# %%
#%tensorboard --logdir=tensorboard

# %% [markdown]
# **Review Results**

# %%
label_val=data_val[WINDOW_SIZE:,1]  # labels start at first value plus window
last=denorm_close(forecast[-1])
yesterday=denorm_close(forecast[-2])
true=denorm_close(label_val[-1])
print ('As of              : {}'.format(dates[-1]))
print ('Yesterday forecast : {:,.0f}'.format(yesterday))
print ("Today's close      : {:,.0f}".format(true))
print ('Percent error      : {:.2f}%'.format((yesterday-true)*100/true))
print ("Tomorrow's forecast: {:,.0f}".format(last))

# Plot forecast vs. actual
plot_series(index_val[WINDOW_SIZE+1:], denorm_close(label_val[1:]))
plot_series(index_val[WINDOW_SIZE+1:], denorm_close(forecast[:-1]),format='r')
plt.title('Prediction vs. Actual')
plt.show()
# Out:
# As of              : 11/28/2022
# Yesterday forecast : 11,277
# Today's close      : 11,049
# Percent error      : 2.06%
# Tomorrow's forecast: 11,285

# %%
def compute_metrics(true_series, forecast):
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()
    return mse, mae

mse, mae = compute_metrics(close_val[WINDOW_SIZE:], forecast.reshape(-1))

print("Forecast vs. labels: mse: {:.5f}, mae: {:.4f}".format(mse,mae))
# Out:
# Forecast vs. labels: mse: 0.00016, mae: 0.0094

# %% [markdown]
# **Make Prediction**

# %%
last_close=denorm_close(data_val[-1,1])

tomorrow_forecast=denorm_close(forecast[-1])
gain_points=tomorrow_forecast-last_close
percent=gain_points/last_close*100.
print("as of                 {}:".format(dates[-1]))
print("today's close       : {:,.0f}".format(last_close))
print("tomorrow's forecast : {:,.0f}".format(tomorrow_forecast))
print("predicted gain of: {:.2f} points or {:.2f}%\n".format(gain_points,percent))
# Out:
# as of                 11/28/2022:
# today's close       : 11,049
# tomorrow's forecast : 11,285
# predicted gain of: 235.79 points or 2.13%

# %% [markdown]
# **Run trading simulation**

# %%
all_in=False
cash=10000.
shares=0
forecast_dates=datadic_val['dates'][WINDOW_SIZE:]
close_actual = denorm_close(close_val[WINDOW_SIZE:])  # actual results from next day to compare to prediction 
forecast_actual = denorm_close(forecast)
days_correct=0
days_incorrect=0

for i in range(1,len(forecast_actual)-1):    # can't use last because no true label
    buyhold=10000.*close_actual[i]/close_actual[1]
    if close_actual[i+1]>close_actual[i] and shares==0: 
        error='Should be invested'
        days_incorrect+=1
    elif close_actual[i+1]<close_actual[i] and cash==0:
        error='Should be cash'
        days_incorrect+=1
    else: 
        error='Correct'
        days_correct+=1
    print('date: {}   Close: {:,.0f}  Forecast: {:,.0f}  Cash:{:,.0f}  Shares:{:,.2f} Total:{:,.0f} BH:{:,.2f}  {}'.format(\
        forecast_dates[i],close_actual[i], forecast_actual[i],cash,shares,\
        cash+shares*close_actual[i], buyhold,error ))
    
    if  forecast_actual[i]>close_actual[i-1] and all_in is False:
        all_in =True
        shares=cash/close_actual[i-1]
        cash=0
        print ('buying {:.2f} shares at {:,.0f}'.format(shares,close_actual[i]))
        
    if forecast_actual[i]<close_actual[i-1] and all_in is True:
        print ('selling {:.2f} shares at {:,.0f}'.format(shares,close_actual[i]))
        all_in = False
        cash=shares*close_actual[i-1]
        shares=0
    
return_ai=cash+shares*close_actual[-1] 
return_bh=10000*close_actual[-1]/close_actual[1]
print('\ndays correct: {}       days incorrect: {}'.format(days_correct, days_incorrect) )
print('total wealth: ${:,.0f}   total with B&H: ${:,.0f}'.format(return_ai,10000*close_actual[-1]/close_actual[1]))
print('\nPercent improvement: {:.2f}%'.format(100*(return_ai-return_bh)/return_bh))
# Out:
# date: 5/9/2019   Close: 7,911  Forecast: 7,950  Cash:10,000  Shares:0.00 Total:10,000 BH:10,000.00  Should be invested
# buying 1.26 shares at 7,911
# date: 5/10/2019   Close: 7,917  Forecast: 7,905  Cash:0  Shares:1.26 Total:9,967 BH:10,008.03  Should be cash
# selling 1.26 shares at 7,917
# date: 5/13/2019   Close: 7,647  Forecast: 7,920  Cash:9,959  Shares:0.00 Total:9,959 BH:9,666.81  Should be invested
# buying 1.26 shares at 7,647
# date: 5/14/2019   Close: 7,734  Forecast: 7,657  Cash:0  Shares:1.26 Total:9,729 BH:9,777.39  Correct
# date: 5/15/2019   Close: 7,822  Forecast: 7,752  Cash:0  Shares:1.26 Total:9,840 BH:9,888.20  Correct
# date: 5/16/2019   Close: 7,898  Forecast: 7,838  Cash:0  Shares:1.26 Total:9,935 BH:9,984.15  Should be cash
# date: 5/17/2019   Close: 7,816  Forecast: 7,897  Cash:0  Shares:1.26 Total:9,832 BH:9,880.78  Should be cash
# selling 1.26 shares at 7,816
# date: 5/20/2019   Close: 7,702  Forecast: 7,817  Cash:9,935  Shares:0.00 Total:9,935 BH:9,736.80  Should be invested
# buying 1.27 shares at 7,702
# date: 5/21/2019   Close: 7,786  Forecast: 7,718  Cash:0  Shares:1.27 Total:9,896 BH:9,842.15  Should be cash
# date: 5/22/2019   Close: 7,751  Forecast: 7,800  Cash:0  Shares:1.27 Total:9,852 BH:9,798.06  Should be cash
# date: 5/23/2019   Close: 7,628  Forecast: 7,760  Cash:0  Shares:1.27 Total:9,696 BH:9,643.12  Correct
# date: 5/24/2019   Close: 7,637  Forecast: 7,631  Cash:0  Shares:1.27 Total:9,707 BH:9,654.16  Should be cash
# date: 5/28/2019   Close: 7,607  Forecast: 7,651  Cash:0  Shares:1.27 Total:9,669 BH:9,616.67  Should be cash
# date: 5/29/2019   Close: 7,547  Forecast: 7,618  Cash:0  Shares:1.27 Total:9,593 BH:9,540.77  Correct
# date: 5/30/2019   Close: 7,568  Forecast: 7,552  Cash:0  Shares:1.27 Total:9,619 BH:9,566.57  Should be cash
# date: 5/31/2019   Close: 7,453  Forecast: 7,588  Cash:0  Shares:1.27 Total:9,473 BH:9,421.74  Should be cash
# date: 6/3/2019   Close: 7,333  Forecast: 7,450  Cash:0  Shares:1.27 Total:9,321 BH:9,269.88  Correct
# selling 1.27 shares at 7,333
# date: 6/4/2019   Close: 7,527  Forecast: 7,351  Cash:9,473  Shares:0.00 Total:9,473 BH:9,515.25  Should be invested
# buying 1.29 shares at 7,527
# date: 6/5/2019   Close: 7,575  Forecast: 7,536  Cash:0  Shares:1.29 Total:9,787 BH:9,576.38  Correct
# date: 6/6/2019   Close: 7,616  Forecast: 7,590  Cash:0  Shares:1.29 Total:9,838 BH:9,627.03  Correct
# date: 6/7/2019   Close: 7,742  Forecast: 7,638  Cash:0  Shares:1.29 Total:10,002 BH:9,787.01  Correct
# date: 6/10/2019   Close: 7,823  Forecast: 7,756  Cash:0  Shares:1.29 Total:10,107 BH:9,889.49  Should be cash
# date: 6/11/2019   Close: 7,823  Forecast: 7,843  Cash:0  Shares:1.29 Total:10,106 BH:9,888.73  Should be cash
# date: 6/12/2019   Close: 7,793  Forecast: 7,815  Cash:0  Shares:1.29 Total:10,067 BH:9,851.00  Correct
# selling 1.29 shares at 7,793
# date: 6/13/2019   Close: 7,837  Forecast: 7,805  Cash:10,106  Shares:0.00 Total:10,106 BH:9,907.14  Correct
# buying 1.30 shares at 7,837
# date: 6/14/2019   Close: 7,797  Forecast: 7,848  Cash:0  Shares:1.30 Total:10,111 BH:9,855.98  Correct
# date: 6/17/2019   Close: 7,845  Forecast: 7,799  Cash:0  Shares:1.30 Total:10,174 BH:9,917.11  Correct
# date: 6/18/2019   Close: 7,954  Forecast: 7,865  Cash:0  Shares:1.30 Total:10,315 BH:10,054.72  Correct
# date: 6/19/2019   Close: 7,987  Forecast: 7,961  Cash:0  Shares:1.30 Total:10,358 BH:10,097.00  Correct
# date: 6/20/2019   Close: 8,051  Forecast: 7,990  Cash:0  Shares:1.30 Total:10,441 BH:10,177.93  Should be cash
# date: 6/21/2019   Close: 8,032  Forecast: 8,060  Cash:0  Shares:1.30 Total:10,416 BH:10,153.11  Should be cash
# date: 6/24/2019   Close: 8,006  Forecast: 8,029  Cash:0  Shares:1.30 Total:10,382 BH:10,120.23  Should be cash
# selling 1.30 shares at 8,006
# date: 6/25/2019   Close: 7,885  Forecast: 8,020  Cash:10,416  Shares:0.00 Total:10,416 BH:9,967.30  Should be invested
# buying 1.30 shares at 7,885
# date: 6/26/2019   Close: 7,910  Forecast: 7,879  Cash:0  Shares:1.30 Total:10,291 BH:9,999.22  Correct
# selling 1.30 shares at 7,910
# date: 6/27/2019   Close: 7,968  Forecast: 7,916  Cash:10,258  Shares:0.00 Total:10,258 BH:10,072.27  Should be invested
# buying 1.30 shares at 7,968
# date: 6/28/2019   Close: 8,006  Forecast: 7,975  Cash:0  Shares:1.30 Total:10,383 BH:10,120.91  Correct
# date: 7/1/2019   Close: 8,091  Forecast: 7,996  Cash:0  Shares:1.30 Total:10,493 BH:10,228.26  Correct
# selling 1.30 shares at 8,091
# date: 7/2/2019   Close: 8,109  Forecast: 8,120  Cash:10,383  Shares:0.00 Total:10,383 BH:10,250.93  Should be invested
# buying 1.28 shares at 8,109
# date: 7/3/2019   Close: 8,170  Forecast: 8,119  Cash:0  Shares:1.28 Total:10,485 BH:10,328.22  Should be cash
# date: 7/5/2019   Close: 8,162  Forecast: 8,220  Cash:0  Shares:1.28 Total:10,474 BH:10,317.55  Should be cash
# date: 7/8/2019   Close: 8,098  Forecast: 8,164  Cash:0  Shares:1.28 Total:10,393 BH:10,237.39  Correct
# date: 7/9/2019   Close: 8,142  Forecast: 8,116  Cash:0  Shares:1.28 Total:10,448 BH:10,292.19  Correct
# date: 7/10/2019   Close: 8,203  Forecast: 8,130  Cash:0  Shares:1.28 Total:10,526 BH:10,369.05  Should be cash
# selling 1.28 shares at 8,203
# date: 7/11/2019   Close: 8,196  Forecast: 8,208  Cash:10,448  Shares:0.00 Total:10,448 BH:10,360.85  Should be invested
# buying 1.27 shares at 8,196
# date: 7/12/2019   Close: 8,244  Forecast: 8,218  Cash:0  Shares:1.27 Total:10,501 BH:10,421.65  Correct
# date: 7/15/2019   Close: 8,258  Forecast: 8,268  Cash:0  Shares:1.27 Total:10,519 BH:10,439.41  Should be cash
# date: 7/16/2019   Close: 8,223  Forecast: 8,267  Cash:0  Shares:1.27 Total:10,474 BH:10,394.67  Should be cash
# date: 7/17/2019   Close: 8,185  Forecast: 8,236  Cash:0  Shares:1.27 Total:10,426 BH:10,347.16  Correct
# date: 7/18/2019   Close: 8,207  Forecast: 8,187  Cash:0  Shares:1.27 Total:10,454 BH:10,375.00  Should be cash
# date: 7/19/2019   Close: 8,146  Forecast: 8,205  Cash:0  Shares:1.27 Total:10,377 BH:10,298.21  Correct
# selling 1.27 shares at 8,146
# date: 7/22/2019   Close: 8,204  Forecast: 8,154  Cash:10,454  Shares:0.00 Total:10,454 BH:10,371.08  Should be invested
# buying 1.28 shares at 8,204
# date: 7/23/2019   Close: 8,251  Forecast: 8,239  Cash:0  Shares:1.28 Total:10,589 BH:10,430.83  Correct
# date: 7/24/2019   Close: 8,322  Forecast: 8,268  Cash:0  Shares:1.28 Total:10,679 BH:10,519.44  Should be cash
# date: 7/25/2019   Close: 8,239  Forecast: 8,324  Cash:0  Shares:1.28 Total:10,572 BH:10,414.57  Correct
# date: 7/26/2019   Close: 8,330  Forecast: 8,233  Cash:0  Shares:1.28 Total:10,690 BH:10,530.45  Should be cash
# selling 1.28 shares at 8,330
# date: 7/29/2019   Close: 8,293  Forecast: 8,340  Cash:10,572  Shares:0.00 Total:10,572 BH:10,483.83  Correct
# buying 1.27 shares at 8,293
# date: 7/30/2019   Close: 8,274  Forecast: 8,307  Cash:0  Shares:1.27 Total:10,500 BH:10,458.90  Should be cash
# date: 7/31/2019   Close: 8,175  Forecast: 8,310  Cash:0  Shares:1.27 Total:10,376 BH:10,334.78  Should be cash
# date: 8/1/2019   Close: 8,111  Forecast: 8,159  Cash:0  Shares:1.27 Total:10,294 BH:10,253.50  Should be cash
# selling 1.27 shares at 8,111
# date: 8/2/2019   Close: 8,004  Forecast: 8,115  Cash:10,376  Shares:0.00 Total:10,376 BH:10,118.17  Correct
# buying 1.28 shares at 8,004
# date: 8/5/2019   Close: 7,726  Forecast: 8,016  Cash:0  Shares:1.28 Total:9,883 BH:9,766.71  Correct
# date: 8/6/2019   Close: 7,833  Forecast: 7,734  Cash:0  Shares:1.28 Total:10,020 BH:9,902.26  Correct
# date: 8/7/2019   Close: 7,863  Forecast: 7,859  Cash:0  Shares:1.28 Total:10,058 BH:9,939.63  Correct
# date: 8/8/2019   Close: 8,039  Forecast: 7,867  Cash:0  Shares:1.28 Total:10,284 BH:10,162.53  Should be cash
# date: 8/9/2019   Close: 7,959  Forecast: 8,044  Cash:0  Shares:1.28 Total:10,181 BH:10,061.37  Should be cash
# date: 8/12/2019   Close: 7,863  Forecast: 7,970  Cash:0  Shares:1.28 Total:10,059 BH:9,940.36  Correct
# date: 8/13/2019   Close: 8,016  Forecast: 7,878  Cash:0  Shares:1.28 Total:10,255 BH:10,133.71  Should be cash
# date: 8/14/2019   Close: 7,774  Forecast: 8,018  Cash:0  Shares:1.28 Total:9,945 BH:9,827.26  Should be cash
# date: 8/15/2019   Close: 7,767  Forecast: 7,779  Cash:0  Shares:1.28 Total:9,935 BH:9,818.00  Correct
# date: 8/16/2019   Close: 7,896  Forecast: 7,774  Cash:0  Shares:1.28 Total:10,101 BH:9,981.54  Correct
# date: 8/19/2019   Close: 8,003  Forecast: 7,911  Cash:0  Shares:1.28 Total:10,237 BH:10,116.58  Should be cash
# date: 8/20/2019   Close: 7,949  Forecast: 8,010  Cash:0  Shares:1.28 Total:10,168 BH:10,048.00  Correct
# date: 8/21/2019   Close: 8,020  Forecast: 7,971  Cash:0  Shares:1.28 Total:10,260 BH:10,138.57  Should be cash
# date: 8/22/2019   Close: 7,991  Forecast: 8,022  Cash:0  Shares:1.28 Total:10,223 BH:10,102.14  Should be cash
# date: 8/23/2019   Close: 7,752  Forecast: 7,994  Cash:0  Shares:1.28 Total:9,916 BH:9,799.23  Correct
# date: 8/26/2019   Close: 7,854  Forecast: 7,766  Cash:0  Shares:1.28 Total:10,047 BH:9,928.13  Should be cash
# date: 8/27/2019   Close: 7,827  Forecast: 7,872  Cash:0  Shares:1.28 Total:10,012 BH:9,894.27  Correct
# date: 8/28/2019   Close: 7,857  Forecast: 7,848  Cash:0  Shares:1.28 Total:10,051 BH:9,932.10  Correct
# date: 8/29/2019   Close: 7,973  Forecast: 7,864  Cash:0  Shares:1.28 Total:10,200 BH:10,079.39  Should be cash
# date: 8/30/2019   Close: 7,963  Forecast: 7,981  Cash:0  Shares:1.28 Total:10,186 BH:10,066.10  Should be cash
# date: 9/3/2019   Close: 7,874  Forecast: 7,968  Cash:0  Shares:1.28 Total:10,073 BH:9,953.95  Correct
# date: 9/4/2019   Close: 7,977  Forecast: 7,891  Cash:0  Shares:1.28 Total:10,204 BH:10,083.80  Correct
# date: 9/5/2019   Close: 8,117  Forecast: 7,991  Cash:0  Shares:1.28 Total:10,383 BH:10,260.71  Should be cash
# date: 9/6/2019   Close: 8,103  Forecast: 8,121  Cash:0  Shares:1.28 Total:10,366 BH:10,243.32  Should be cash
# date: 9/9/2019   Close: 8,087  Forecast: 8,115  Cash:0  Shares:1.28 Total:10,346 BH:10,223.56  Should be cash
# date: 9/10/2019   Close: 8,084  Forecast: 8,093  Cash:0  Shares:1.28 Total:10,341 BH:10,219.42  Correct
# date: 9/11/2019   Close: 8,170  Forecast: 8,088  Cash:0  Shares:1.28 Total:10,451 BH:10,327.52  Correct
# date: 9/12/2019   Close: 8,194  Forecast: 8,187  Cash:0  Shares:1.28 Total:10,482 BH:10,358.86  Should be cash
# date: 9/13/2019   Close: 8,177  Forecast: 8,194  Cash:0  Shares:1.28 Total:10,460 BH:10,336.41  Should be cash
# selling 1.28 shares at 8,177
# date: 9/16/2019   Close: 8,154  Forecast: 8,187  Cash:10,482  Shares:0.00 Total:10,482 BH:10,307.12  Should be invested
# buying 1.28 shares at 8,154
# date: 9/17/2019   Close: 8,186  Forecast: 8,163  Cash:0  Shares:1.28 Total:10,494 BH:10,348.18  Should be cash
# date: 9/18/2019   Close: 8,177  Forecast: 8,189  Cash:0  Shares:1.28 Total:10,483 BH:10,337.27  Correct
# date: 9/19/2019   Close: 8,183  Forecast: 8,189  Cash:0  Shares:1.28 Total:10,490 BH:10,344.21  Should be cash
# date: 9/20/2019   Close: 8,118  Forecast: 8,196  Cash:0  Shares:1.28 Total:10,407 BH:10,261.78  Should be cash
# date: 9/23/2019   Close: 8,112  Forecast: 8,112  Cash:0  Shares:1.28 Total:10,400 BH:10,255.19  Should be cash
# selling 1.28 shares at 8,112
# date: 9/24/2019   Close: 7,994  Forecast: 8,125  Cash:10,407  Shares:0.00 Total:10,407 BH:10,104.97  Should be invested
# buying 1.28 shares at 7,994
# date: 9/25/2019   Close: 8,077  Forecast: 7,993  Cash:0  Shares:1.28 Total:10,362 BH:10,210.84  Should be cash
# selling 1.28 shares at 8,077
# date: 9/26/2019   Close: 8,031  Forecast: 8,081  Cash:10,254  Shares:0.00 Total:10,254 BH:10,151.78  Correct
# buying 1.27 shares at 8,031
# date: 9/27/2019   Close: 7,940  Forecast: 8,033  Cash:0  Shares:1.27 Total:10,079 BH:10,036.71  Correct
# date: 9/30/2019   Close: 7,999  Forecast: 7,934  Cash:0  Shares:1.27 Total:10,155 BH:10,112.19  Should be cash
# selling 1.27 shares at 7,999
# date: 10/1/2019   Close: 7,909  Forecast: 8,003  Cash:10,079  Shares:0.00 Total:10,079 BH:9,997.59  Correct
# buying 1.26 shares at 7,909
# date: 10/2/2019   Close: 7,785  Forecast: 7,916  Cash:0  Shares:1.26 Total:9,810 BH:9,841.55  Correct
# date: 10/3/2019   Close: 7,872  Forecast: 7,799  Cash:0  Shares:1.26 Total:9,919 BH:9,951.55  Correct
# date: 10/4/2019   Close: 7,982  Forecast: 7,895  Cash:0  Shares:1.26 Total:10,058 BH:10,090.87  Should be cash
# date: 10/7/2019   Close: 7,956  Forecast: 8,003  Cash:0  Shares:1.26 Total:10,025 BH:10,057.77  Should be cash
# date: 10/8/2019   Close: 7,824  Forecast: 7,977  Cash:0  Shares:1.26 Total:9,858 BH:9,890.26  Correct
# date: 10/9/2019   Close: 7,904  Forecast: 7,834  Cash:0  Shares:1.26 Total:9,959 BH:9,991.34  Correct
# date: 10/10/2019   Close: 7,951  Forecast: 7,908  Cash:0  Shares:1.26 Total:10,018 BH:10,050.81  Correct
# date: 10/11/2019   Close: 8,057  Forecast: 7,965  Cash:0  Shares:1.26 Total:10,152 BH:10,185.13  Should be cash
# date: 10/14/2019   Close: 8,049  Forecast: 8,076  Cash:0  Shares:1.26 Total:10,142 BH:10,174.53  Correct
# date: 10/15/2019   Close: 8,149  Forecast: 8,061  Cash:0  Shares:1.26 Total:10,268 BH:10,301.01  Should be cash
# date: 10/16/2019   Close: 8,124  Forecast: 8,165  Cash:0  Shares:1.26 Total:10,237 BH:10,270.01  Correct
# date: 10/17/2019   Close: 8,157  Forecast: 8,125  Cash:0  Shares:1.26 Total:10,278 BH:10,311.30  Should be cash
# date: 10/18/2019   Close: 8,090  Forecast: 8,169  Cash:0  Shares:1.26 Total:10,193 BH:10,226.22  Correct
# date: 10/21/2019   Close: 8,163  Forecast: 8,095  Cash:0  Shares:1.26 Total:10,286 BH:10,319.07  Should be cash
# date: 10/22/2019   Close: 8,104  Forecast: 8,190  Cash:0  Shares:1.26 Total:10,212 BH:10,244.87  Correct
# date: 10/23/2019   Close: 8,120  Forecast: 8,086  Cash:0  Shares:1.26 Total:10,231 BH:10,264.46  Correct
# selling 1.26 shares at 8,120
# date: 10/24/2019   Close: 8,186  Forecast: 8,136  Cash:10,212  Shares:0.00 Total:10,212 BH:10,347.90  Should be invested
# buying 1.26 shares at 8,186
# date: 10/25/2019   Close: 8,243  Forecast: 8,185  Cash:0  Shares:1.26 Total:10,367 BH:10,420.36  Correct
# selling 1.26 shares at 8,243
# date: 10/28/2019   Close: 8,326  Forecast: 8,254  Cash:10,295  Shares:0.00 Total:10,295 BH:10,525.12  Correct
# buying 1.25 shares at 8,326
# date: 10/29/2019   Close: 8,277  Forecast: 8,359  Cash:0  Shares:1.25 Total:10,337 BH:10,463.00  Correct
# date: 10/30/2019   Close: 8,304  Forecast: 8,272  Cash:0  Shares:1.25 Total:10,371 BH:10,497.30  Should be cash
# selling 1.25 shares at 8,304
# date: 10/31/2019   Close: 8,292  Forecast: 8,318  Cash:10,337  Shares:0.00 Total:10,337 BH:10,482.61  Should be invested
# buying 1.24 shares at 8,292
# date: 11/1/2019   Close: 8,386  Forecast: 8,308  Cash:0  Shares:1.24 Total:10,439 BH:10,601.49  Correct
# date: 11/4/2019   Close: 8,433  Forecast: 8,382  Cash:0  Shares:1.24 Total:10,498 BH:10,660.65  Correct
# selling 1.24 shares at 8,433
# date: 11/5/2019   Close: 8,435  Forecast: 8,446  Cash:10,439  Shares:0.00 Total:10,439 BH:10,662.52  Correct
# buying 1.24 shares at 8,435
# date: 11/6/2019   Close: 8,411  Forecast: 8,435  Cash:0  Shares:1.24 Total:10,412 BH:10,632.11  Correct
# date: 11/7/2019   Close: 8,435  Forecast: 8,422  Cash:0  Shares:1.24 Total:10,441 BH:10,662.31  Correct
# date: 11/8/2019   Close: 8,475  Forecast: 8,446  Cash:0  Shares:1.24 Total:10,492 BH:10,713.88  Should be cash
# date: 11/11/2019   Close: 8,464  Forecast: 8,480  Cash:0  Shares:1.24 Total:10,478 BH:10,699.94  Correct
# date: 11/12/2019   Close: 8,486  Forecast: 8,480  Cash:0  Shares:1.24 Total:10,505 BH:10,727.51  Should be cash
# date: 11/13/2019   Close: 8,482  Forecast: 8,496  Cash:0  Shares:1.24 Total:10,500 BH:10,722.46  Should be cash
# date: 11/14/2019   Close: 8,479  Forecast: 8,495  Cash:0  Shares:1.24 Total:10,496 BH:10,718.57  Correct
# date: 11/15/2019   Close: 8,541  Forecast: 8,469  Cash:0  Shares:1.24 Total:10,573 BH:10,796.70  Correct
# selling 1.24 shares at 8,541
# date: 11/18/2019   Close: 8,550  Forecast: 8,549  Cash:10,496  Shares:0.00 Total:10,496 BH:10,808.22  Should be invested
# buying 1.23 shares at 8,550
# date: 11/19/2019   Close: 8,571  Forecast: 8,556  Cash:0  Shares:1.23 Total:10,533 BH:10,834.41  Should be cash
# date: 11/20/2019   Close: 8,527  Forecast: 8,562  Cash:0  Shares:1.23 Total:10,479 BH:10,778.88  Should be cash
# selling 1.23 shares at 8,527
# date: 11/21/2019   Close: 8,506  Forecast: 8,542  Cash:10,533  Shares:0.00 Total:10,533 BH:10,752.94  Should be invested
# buying 1.24 shares at 8,506
# date: 11/22/2019   Close: 8,520  Forecast: 8,506  Cash:0  Shares:1.24 Total:10,524 BH:10,770.22  Correct
# selling 1.24 shares at 8,520
# date: 11/25/2019   Close: 8,632  Forecast: 8,535  Cash:10,508  Shares:0.00 Total:10,508 BH:10,912.57  Should be invested
# buying 1.23 shares at 8,632
# date: 11/26/2019   Close: 8,648  Forecast: 8,638  Cash:0  Shares:1.23 Total:10,665 BH:10,932.09  Correct
# date: 11/27/2019   Close: 8,705  Forecast: 8,662  Cash:0  Shares:1.23 Total:10,736 BH:11,004.46  Should be cash
# date: 11/29/2019   Close: 8,665  Forecast: 8,726  Cash:0  Shares:1.23 Total:10,687 BH:10,954.26  Should be cash
# date: 12/2/2019   Close: 8,568  Forecast: 8,687  Cash:0  Shares:1.23 Total:10,567 BH:10,831.04  Should be cash
# date: 12/3/2019   Close: 8,521  Forecast: 8,582  Cash:0  Shares:1.23 Total:10,508 BH:10,771.18  Correct
# date: 12/4/2019   Close: 8,567  Forecast: 8,541  Cash:0  Shares:1.23 Total:10,565 BH:10,829.37  Correct
# date: 12/5/2019   Close: 8,571  Forecast: 8,587  Cash:0  Shares:1.23 Total:10,570 BH:10,834.46  Correct
# date: 12/6/2019   Close: 8,657  Forecast: 8,563  Cash:0  Shares:1.23 Total:10,676 BH:10,942.96  Should be cash
# selling 1.23 shares at 8,657
# date: 12/9/2019   Close: 8,622  Forecast: 8,681  Cash:10,570  Shares:0.00 Total:10,570 BH:10,899.10  Correct
# buying 1.22 shares at 8,622
# date: 12/10/2019   Close: 8,616  Forecast: 8,620  Cash:0  Shares:1.22 Total:10,521 BH:10,891.96  Correct
# selling 1.22 shares at 8,616
# date: 12/11/2019   Close: 8,654  Forecast: 8,622  Cash:10,528  Shares:0.00 Total:10,528 BH:10,939.83  Should be invested
# buying 1.22 shares at 8,654
# date: 12/12/2019   Close: 8,717  Forecast: 8,666  Cash:0  Shares:1.22 Total:10,651 BH:11,019.81  Correct
# date: 12/13/2019   Close: 8,735  Forecast: 8,729  Cash:0  Shares:1.22 Total:10,673 BH:11,042.01  Correct
# date: 12/16/2019   Close: 8,814  Forecast: 8,747  Cash:0  Shares:1.22 Total:10,770 BH:11,142.32  Correct
# date: 12/17/2019   Close: 8,823  Forecast: 8,814  Cash:0  Shares:1.22 Total:10,781 BH:11,153.86  Correct
# date: 12/18/2019   Close: 8,828  Forecast: 8,840  Cash:0  Shares:1.22 Total:10,786 BH:11,159.40  Correct
# date: 12/19/2019   Close: 8,887  Forecast: 8,819  Cash:0  Shares:1.22 Total:10,859 BH:11,234.59  Correct
# selling 1.22 shares at 8,887
# date: 12/20/2019   Close: 8,925  Forecast: 8,886  Cash:10,786  Shares:0.00 Total:10,786 BH:11,282.29  Should be invested
# date: 12/23/2019   Close: 8,946  Forecast: 8,909  Cash:10,786  Shares:0.00 Total:10,786 BH:11,308.45  Should be invested
# date: 12/24/2019   Close: 8,953  Forecast: 8,972  Cash:10,786  Shares:0.00 Total:10,786 BH:11,317.59  Should be invested
# buying 1.21 shares at 8,953
# date: 12/26/2019   Close: 9,022  Forecast: 8,995  Cash:0  Shares:1.21 Total:10,879 BH:11,405.46  Should be cash
# date: 12/27/2019   Close: 9,007  Forecast: 9,012  Cash:0  Shares:1.21 Total:10,860 BH:11,385.52  Should be cash
# selling 1.21 shares at 9,007
# date: 12/30/2019   Close: 8,946  Forecast: 9,014  Cash:10,879  Shares:0.00 Total:10,879 BH:11,308.88  Should be invested
# buying 1.21 shares at 8,946
# date: 12/31/2019   Close: 8,973  Forecast: 8,991  Cash:0  Shares:1.21 Total:10,838 BH:11,342.52  Correct
# date: 1/2/2020   Close: 9,092  Forecast: 8,964  Cash:0  Shares:1.21 Total:10,982 BH:11,493.69  Should be cash
# selling 1.21 shares at 9,092
# date: 1/3/2020   Close: 9,021  Forecast: 9,115  Cash:10,838  Shares:0.00 Total:10,838 BH:11,403.41  Should be invested
# buying 1.19 shares at 9,021
# date: 1/6/2020   Close: 9,071  Forecast: 9,046  Cash:0  Shares:1.19 Total:10,813 BH:11,467.50  Should be cash
# date: 1/7/2020   Close: 9,069  Forecast: 9,096  Cash:0  Shares:1.19 Total:10,810 BH:11,463.85  Correct
# date: 1/8/2020   Close: 9,129  Forecast: 9,050  Cash:0  Shares:1.19 Total:10,882 BH:11,540.53  Correct
# selling 1.19 shares at 9,129
# date: 1/9/2020   Close: 9,203  Forecast: 9,125  Cash:10,810  Shares:0.00 Total:10,810 BH:11,634.32  Correct
# date: 1/10/2020   Close: 9,179  Forecast: 9,218  Cash:10,810  Shares:0.00 Total:10,810 BH:11,603.26  Should be invested
# buying 1.17 shares at 9,179
# date: 1/13/2020   Close: 9,274  Forecast: 9,170  Cash:0  Shares:1.17 Total:10,892 BH:11,723.44  Should be cash
# selling 1.17 shares at 9,274
# date: 1/14/2020   Close: 9,251  Forecast: 9,299  Cash:10,781  Shares:0.00 Total:10,781 BH:11,694.87  Should be invested
# buying 1.16 shares at 9,251
# date: 1/15/2020   Close: 9,259  Forecast: 9,282  Cash:0  Shares:1.16 Total:10,763 BH:11,704.18  Correct
# date: 1/16/2020   Close: 9,357  Forecast: 9,266  Cash:0  Shares:1.16 Total:10,877 BH:11,828.61  Correct
# date: 1/17/2020   Close: 9,389  Forecast: 9,376  Cash:0  Shares:1.16 Total:10,914 BH:11,868.82  Should be cash
# date: 1/21/2020   Close: 9,371  Forecast: 9,361  Cash:0  Shares:1.16 Total:10,893 BH:11,845.90  Correct
# selling 1.16 shares at 9,371
# date: 1/22/2020   Close: 9,384  Forecast: 9,356  Cash:10,914  Shares:0.00 Total:10,914 BH:11,862.29  Should be invested
# date: 1/23/2020   Close: 9,402  Forecast: 9,381  Cash:10,914  Shares:0.00 Total:10,914 BH:11,885.94  Correct
# date: 1/24/2020   Close: 9,315  Forecast: 9,419  Cash:10,914  Shares:0.00 Total:10,914 BH:11,775.24  Correct
# buying 1.16 shares at 9,315
# date: 1/27/2020   Close: 9,139  Forecast: 9,306  Cash:0  Shares:1.16 Total:10,609 BH:11,553.26  Correct
# selling 1.16 shares at 9,139
# date: 1/28/2020   Close: 9,270  Forecast: 9,136  Cash:10,813  Shares:0.00 Total:10,813 BH:11,718.06  Should be invested
# date: 1/29/2020   Close: 9,275  Forecast: 9,295  Cash:10,813  Shares:0.00 Total:10,813 BH:11,724.99  Should be invested
# buying 1.17 shares at 9,275
# date: 1/30/2020   Close: 9,299  Forecast: 9,317  Cash:0  Shares:1.17 Total:10,847 BH:11,755.04  Should be cash
# date: 1/31/2020   Close: 9,151  Forecast: 9,334  Cash:0  Shares:1.17 Total:10,674 BH:11,567.96  Correct
# date: 2/3/2020   Close: 9,273  Forecast: 9,160  Cash:0  Shares:1.17 Total:10,817 BH:11,722.77  Correct
# date: 2/4/2020   Close: 9,468  Forecast: 9,281  Cash:0  Shares:1.17 Total:11,044 BH:11,968.73  Correct
# date: 2/5/2020   Close: 9,509  Forecast: 9,480  Cash:0  Shares:1.17 Total:11,092 BH:12,020.19  Correct
# date: 2/6/2020   Close: 9,572  Forecast: 9,527  Cash:0  Shares:1.17 Total:11,166 BH:12,100.43  Should be cash
# date: 2/7/2020   Close: 9,521  Forecast: 9,572  Cash:0  Shares:1.17 Total:11,105 BH:12,035.15  Correct
# date: 2/10/2020   Close: 9,628  Forecast: 9,534  Cash:0  Shares:1.17 Total:11,231 BH:12,171.52  Correct
# date: 2/11/2020   Close: 9,639  Forecast: 9,651  Cash:0  Shares:1.17 Total:11,244 BH:12,184.86  Correct
# date: 2/12/2020   Close: 9,726  Forecast: 9,649  Cash:0  Shares:1.17 Total:11,345 BH:12,294.86  Should be cash
# date: 2/13/2020   Close: 9,712  Forecast: 9,742  Cash:0  Shares:1.17 Total:11,329 BH:12,277.18  Correct
# date: 2/14/2020   Close: 9,731  Forecast: 9,725  Cash:0  Shares:1.17 Total:11,351 BH:12,301.46  Correct
# date: 2/18/2020   Close: 9,733  Forecast: 9,742  Cash:0  Shares:1.17 Total:11,353 BH:12,303.43  Correct
# date: 2/19/2020   Close: 9,817  Forecast: 9,748  Cash:0  Shares:1.17 Total:11,451 BH:12,410.17  Should be cash
# date: 2/20/2020   Close: 9,751  Forecast: 9,814  Cash:0  Shares:1.17 Total:11,374 BH:12,326.48  Should be cash
# selling 1.17 shares at 9,751
# date: 2/21/2020   Close: 9,577  Forecast: 9,761  Cash:11,451  Shares:0.00 Total:11,451 BH:12,106.04  Correct
# buying 1.17 shares at 9,577
# date: 2/24/2020   Close: 9,221  Forecast: 9,581  Cash:0  Shares:1.17 Total:10,829 BH:11,656.88  Should be cash
# date: 2/25/2020   Close: 8,966  Forecast: 9,203  Cash:0  Shares:1.17 Total:10,529 BH:11,333.68  Correct
# selling 1.17 shares at 8,966
# date: 2/26/2020   Close: 8,981  Forecast: 8,948  Cash:10,829  Shares:0.00 Total:10,829 BH:11,352.86  Correct
# date: 2/27/2020   Close: 8,566  Forecast: 8,972  Cash:10,829  Shares:0.00 Total:10,829 BH:10,829.13  Should be invested
# date: 2/28/2020   Close: 8,567  Forecast: 8,527  Cash:10,829  Shares:0.00 Total:10,829 BH:10,830.25  Should be invested
# date: 3/2/2020   Close: 8,952  Forecast: 8,519  Cash:10,829  Shares:0.00 Total:10,829 BH:11,316.69  Correct
# date: 3/3/2020   Close: 8,684  Forecast: 8,983  Cash:10,829  Shares:0.00 Total:10,829 BH:10,977.80  Should be invested
# buying 1.21 shares at 8,684
# date: 3/4/2020   Close: 9,018  Forecast: 8,690  Cash:0  Shares:1.21 Total:10,909 BH:11,400.02  Should be cash
# date: 3/5/2020   Close: 8,739  Forecast: 9,009  Cash:0  Shares:1.21 Total:10,571 BH:11,046.70  Should be cash
# selling 1.21 shares at 8,739
# date: 3/6/2020   Close: 8,576  Forecast: 8,762  Cash:10,909  Shares:0.00 Total:10,909 BH:10,840.68  Correct
# buying 1.25 shares at 8,576
# date: 3/9/2020   Close: 7,951  Forecast: 8,538  Cash:0  Shares:1.25 Total:9,926 BH:10,050.68  Correct
# selling 1.25 shares at 7,951
# date: 3/10/2020   Close: 8,344  Forecast: 7,910  Cash:10,706  Shares:0.00 Total:10,706 BH:10,548.20  Correct
# date: 3/11/2020   Close: 7,952  Forecast: 8,360  Cash:10,706  Shares:0.00 Total:10,706 BH:10,052.41  Correct
# buying 1.28 shares at 7,952
# date: 3/12/2020   Close: 7,202  Forecast: 7,921  Cash:0  Shares:1.28 Total:9,240 BH:9,104.00  Correct
# selling 1.28 shares at 7,202
# date: 3/13/2020   Close: 7,875  Forecast: 7,167  Cash:10,202  Shares:0.00 Total:10,202 BH:9,954.86  Correct
# date: 3/16/2020   Close: 6,905  Forecast: 7,872  Cash:10,202  Shares:0.00 Total:10,202 BH:8,728.29  Should be invested
# date: 3/17/2020   Close: 7,335  Forecast: 6,895  Cash:10,202  Shares:0.00 Total:10,202 BH:9,272.10  Correct
# date: 3/18/2020   Close: 6,990  Forecast: 7,265  Cash:10,202  Shares:0.00 Total:10,202 BH:8,836.05  Should be invested
# date: 3/19/2020   Close: 7,151  Forecast: 6,974  Cash:10,202  Shares:0.00 Total:10,202 BH:9,039.25  Correct
# date: 3/20/2020   Close: 6,880  Forecast: 7,178  Cash:10,202  Shares:0.00 Total:10,202 BH:8,696.60  Correct
# buying 1.43 shares at 6,880
# date: 3/23/2020   Close: 6,861  Forecast: 6,862  Cash:0  Shares:1.43 Total:9,789 BH:8,672.77  Correct
# selling 1.43 shares at 6,861
# date: 3/24/2020   Close: 7,418  Forecast: 6,864  Cash:9,816  Shares:0.00 Total:9,816 BH:9,377.13  Correct
# buying 1.43 shares at 7,418
# date: 3/25/2020   Close: 7,384  Forecast: 7,446  Cash:0  Shares:1.43 Total:10,565 BH:9,334.70  Correct
# date: 3/26/2020   Close: 7,798  Forecast: 7,393  Cash:0  Shares:1.43 Total:11,156 BH:9,857.09  Should be cash
# date: 3/27/2020   Close: 7,502  Forecast: 7,820  Cash:0  Shares:1.43 Total:10,734 BH:9,483.97  Correct
# date: 3/30/2020   Close: 7,774  Forecast: 7,533  Cash:0  Shares:1.43 Total:11,123 BH:9,827.52  Should be cash
# date: 3/31/2020   Close: 7,700  Forecast: 7,772  Cash:0  Shares:1.43 Total:11,017 BH:9,733.91  Should be cash
# selling 1.43 shares at 7,700
# date: 4/1/2020   Close: 7,361  Forecast: 7,661  Cash:11,123  Shares:0.00 Total:11,123 BH:9,304.72  Should be invested
# date: 4/2/2020   Close: 7,487  Forecast: 7,406  Cash:11,123  Shares:0.00 Total:11,123 BH:9,464.92  Correct
# buying 1.51 shares at 7,487
# date: 4/3/2020   Close: 7,373  Forecast: 7,477  Cash:0  Shares:1.51 Total:11,142 BH:9,320.52  Correct
# selling 1.51 shares at 7,373
# date: 4/6/2020   Close: 7,913  Forecast: 7,376  Cash:11,314  Shares:0.00 Total:11,314 BH:10,003.35  Correct
# buying 1.53 shares at 7,913
# date: 4/7/2020   Close: 7,887  Forecast: 7,942  Cash:0  Shares:1.53 Total:12,103 BH:9,970.51  Correct
# date: 4/8/2020   Close: 8,091  Forecast: 7,857  Cash:0  Shares:1.53 Total:12,416 BH:10,227.94  Correct
# selling 1.53 shares at 8,091
# date: 4/9/2020   Close: 8,154  Forecast: 8,121  Cash:12,103  Shares:0.00 Total:12,103 BH:10,307.17  Should be invested
# buying 1.50 shares at 8,154
# date: 4/13/2020   Close: 8,192  Forecast: 8,138  Cash:0  Shares:1.50 Total:12,255 BH:10,356.27  Correct
# selling 1.50 shares at 8,192
# date: 4/14/2020   Close: 8,516  Forecast: 8,229  Cash:12,197  Shares:0.00 Total:12,197 BH:10,764.99  Correct
# buying 1.49 shares at 8,516
# date: 4/15/2020   Close: 8,393  Forecast: 8,520  Cash:0  Shares:1.49 Total:12,496 BH:10,610.06  Correct
# date: 4/16/2020   Close: 8,532  Forecast: 8,407  Cash:0  Shares:1.49 Total:12,703 BH:10,786.00  Correct
# date: 4/17/2020   Close: 8,650  Forecast: 8,532  Cash:0  Shares:1.49 Total:12,878 BH:10,934.89  Should be cash
# selling 1.49 shares at 8,650
# date: 4/20/2020   Close: 8,561  Forecast: 8,625  Cash:12,703  Shares:0.00 Total:12,703 BH:10,821.86  Correct
# date: 4/21/2020   Close: 8,263  Forecast: 8,565  Cash:12,703  Shares:0.00 Total:12,703 BH:10,445.78  Should be invested
# buying 1.48 shares at 8,263
# date: 4/22/2020   Close: 8,495  Forecast: 8,255  Cash:0  Shares:1.48 Total:12,606 BH:10,739.25  Should be cash
# selling 1.48 shares at 8,495
# date: 4/23/2020   Close: 8,495  Forecast: 8,527  Cash:12,262  Shares:0.00 Total:12,262 BH:10,738.45  Should be invested
# buying 1.44 shares at 8,495
# date: 4/24/2020   Close: 8,635  Forecast: 8,478  Cash:0  Shares:1.44 Total:12,462 BH:10,915.14  Correct
# selling 1.44 shares at 8,635
# date: 4/27/2020   Close: 8,730  Forecast: 8,638  Cash:12,261  Shares:0.00 Total:12,261 BH:11,036.04  Correct
# buying 1.42 shares at 8,730
# date: 4/28/2020   Close: 8,608  Forecast: 8,726  Cash:0  Shares:1.42 Total:12,223 BH:10,881.28  Correct
# selling 1.42 shares at 8,608
# date: 4/29/2020   Close: 8,915  Forecast: 8,581  Cash:12,397  Shares:0.00 Total:12,397 BH:11,269.34  Correct
# date: 4/30/2020   Close: 8,890  Forecast: 8,889  Cash:12,397  Shares:0.00 Total:12,397 BH:11,237.53  Correct
# date: 5/1/2020   Close: 8,605  Forecast: 8,834  Cash:12,397  Shares:0.00 Total:12,397 BH:10,877.76  Should be invested
# date: 5/4/2020   Close: 8,711  Forecast: 8,613  Cash:12,397  Shares:0.00 Total:12,397 BH:11,011.45  Should be invested
# buying 1.44 shares at 8,711
# date: 5/5/2020   Close: 8,809  Forecast: 8,704  Cash:0  Shares:1.44 Total:12,691 BH:11,135.86  Correct
# selling 1.44 shares at 8,809
# date: 5/6/2020   Close: 8,854  Forecast: 8,791  Cash:12,549  Shares:0.00 Total:12,549 BH:11,193.08  Should be invested
# date: 5/7/2020   Close: 8,980  Forecast: 8,876  Cash:12,549  Shares:0.00 Total:12,549 BH:11,351.44  Should be invested
# buying 1.42 shares at 8,980
# date: 5/8/2020   Close: 9,121  Forecast: 8,947  Cash:0  Shares:1.42 Total:12,927 BH:11,530.52  Correct
# selling 1.42 shares at 9,121
# date: 5/11/2020   Close: 9,192  Forecast: 9,097  Cash:12,726  Shares:0.00 Total:12,726 BH:11,620.30  Correct
# date: 5/12/2020   Close: 9,003  Forecast: 9,181  Cash:12,726  Shares:0.00 Total:12,726 BH:11,380.38  Correct
# date: 5/13/2020   Close: 8,863  Forecast: 8,964  Cash:12,726  Shares:0.00 Total:12,726 BH:11,204.18  Should be invested
# date: 5/14/2020   Close: 8,944  Forecast: 8,861  Cash:12,726  Shares:0.00 Total:12,726 BH:11,306.01  Should be invested
# date: 5/15/2020   Close: 9,015  Forecast: 8,918  Cash:12,726  Shares:0.00 Total:12,726 BH:11,395.56  Should be invested
# date: 5/18/2020   Close: 9,235  Forecast: 8,986  Cash:12,726  Shares:0.00 Total:12,726 BH:11,674.01  Correct
# date: 5/19/2020   Close: 9,185  Forecast: 9,218  Cash:12,726  Shares:0.00 Total:12,726 BH:11,611.14  Should be invested
# date: 5/20/2020   Close: 9,376  Forecast: 9,166  Cash:12,726  Shares:0.00 Total:12,726 BH:11,852.19  Correct
# date: 5/21/2020   Close: 9,285  Forecast: 9,380  Cash:12,726  Shares:0.00 Total:12,726 BH:11,737.28  Should be invested
# buying 1.36 shares at 9,285
# date: 5/22/2020   Close: 9,325  Forecast: 9,280  Cash:0  Shares:1.36 Total:12,657 BH:11,787.48  Correct
# selling 1.36 shares at 9,325
# date: 5/26/2020   Close: 9,340  Forecast: 9,323  Cash:12,603  Shares:0.00 Total:12,603 BH:11,807.24  Should be invested
# date: 5/27/2020   Close: 9,412  Forecast: 9,327  Cash:12,603  Shares:0.00 Total:12,603 BH:11,898.43  Correct
# date: 5/28/2020   Close: 9,369  Forecast: 9,394  Cash:12,603  Shares:0.00 Total:12,603 BH:11,843.61  Should be invested
# date: 5/29/2020   Close: 9,490  Forecast: 9,362  Cash:12,603  Shares:0.00 Total:12,603 BH:11,996.41  Should be invested
# date: 6/1/2020   Close: 9,552  Forecast: 9,438  Cash:12,603  Shares:0.00 Total:12,603 BH:12,075.02  Should be invested
# date: 6/2/2020   Close: 9,608  Forecast: 9,572  Cash:12,603  Shares:0.00 Total:12,603 BH:12,146.22  Should be invested
# buying 1.32 shares at 9,608
# date: 6/3/2020   Close: 9,683  Forecast: 9,617  Cash:0  Shares:1.32 Total:12,776 BH:12,240.44  Should be cash
# date: 6/4/2020   Close: 9,616  Forecast: 9,636  Cash:0  Shares:1.32 Total:12,687 BH:12,155.62  Correct
# selling 1.32 shares at 9,616
# date: 6/5/2020   Close: 9,814  Forecast: 9,564  Cash:12,776  Shares:0.00 Total:12,776 BH:12,406.26  Should be invested
# date: 6/8/2020   Close: 9,925  Forecast: 9,772  Cash:12,776  Shares:0.00 Total:12,776 BH:12,546.16  Should be invested
# date: 6/9/2020   Close: 9,954  Forecast: 9,901  Cash:12,776  Shares:0.00 Total:12,776 BH:12,582.82  Should be invested
# date: 6/10/2020   Close: 10,020  Forecast: 9,977  Cash:12,776  Shares:0.00 Total:12,776 BH:12,667.01  Correct
# buying 1.28 shares at 10,020
# date: 6/11/2020   Close: 9,493  Forecast: 10,054  Cash:0  Shares:1.28 Total:12,184 BH:12,000.03  Correct
# date: 6/12/2020   Close: 9,589  Forecast: 9,494  Cash:0  Shares:1.28 Total:12,307 BH:12,121.48  Correct
# date: 6/15/2020   Close: 9,726  Forecast: 9,584  Cash:0  Shares:1.28 Total:12,483 BH:12,294.94  Correct
# selling 1.28 shares at 9,726
# date: 6/16/2020   Close: 9,896  Forecast: 9,699  Cash:12,307  Shares:0.00 Total:12,307 BH:12,509.65  Should be invested
# date: 6/17/2020   Close: 9,911  Forecast: 9,892  Cash:12,307  Shares:0.00 Total:12,307 BH:12,528.18  Should be invested
# date: 6/18/2020   Close: 9,943  Forecast: 9,937  Cash:12,307  Shares:0.00 Total:12,307 BH:12,569.29  Should be invested
# buying 1.24 shares at 9,943
# date: 6/19/2020   Close: 9,946  Forecast: 9,932  Cash:0  Shares:1.24 Total:12,351 BH:12,573.17  Correct
# selling 1.24 shares at 9,946
# date: 6/22/2020   Close: 10,056  Forecast: 9,878  Cash:12,348  Shares:0.00 Total:12,348 BH:12,712.68  Should be invested
# date: 6/23/2020   Close: 10,131  Forecast: 10,082  Cash:12,348  Shares:0.00 Total:12,348 BH:12,807.35  Correct
# buying 1.23 shares at 10,131
# date: 6/24/2020   Close: 9,909  Forecast: 10,082  Cash:0  Shares:1.23 Total:12,167 BH:12,526.46  Correct
# selling 1.23 shares at 9,909
# date: 6/25/2020   Close: 10,017  Forecast: 9,841  Cash:12,440  Shares:0.00 Total:12,440 BH:12,662.77  Correct
# date: 6/26/2020   Close: 9,757  Forecast: 10,086  Cash:12,440  Shares:0.00 Total:12,440 BH:12,334.38  Should be invested
# buying 1.24 shares at 9,757
# date: 6/29/2020   Close: 9,874  Forecast: 9,724  Cash:0  Shares:1.24 Total:12,262 BH:12,482.19  Correct
# selling 1.24 shares at 9,874
# date: 6/30/2020   Close: 10,059  Forecast: 9,923  Cash:12,117  Shares:0.00 Total:12,117 BH:12,715.57  Should be invested
# buying 1.23 shares at 10,059
# date: 7/1/2020   Close: 10,155  Forecast: 10,128  Cash:0  Shares:1.23 Total:12,461 BH:12,836.75  Correct
# date: 7/2/2020   Close: 10,208  Forecast: 10,176  Cash:0  Shares:1.23 Total:12,526 BH:12,903.75  Correct
# date: 7/6/2020   Close: 10,434  Forecast: 10,213  Cash:0  Shares:1.23 Total:12,804 BH:13,189.47  Should be cash
# date: 7/7/2020   Close: 10,344  Forecast: 10,565  Cash:0  Shares:1.23 Total:12,693 BH:13,076.00  Correct
# date: 7/8/2020   Close: 10,492  Forecast: 10,311  Cash:0  Shares:1.23 Total:12,876 BH:13,263.87  Correct
# selling 1.23 shares at 10,492
# date: 7/9/2020   Close: 10,548  Forecast: 10,493  Cash:12,693  Shares:0.00 Total:12,693 BH:13,333.71  Should be invested
# buying 1.21 shares at 10,548
# date: 7/10/2020   Close: 10,617  Forecast: 10,603  Cash:0  Shares:1.21 Total:12,845 BH:13,421.81  Should be cash
# date: 7/13/2020   Close: 10,391  Forecast: 10,622  Cash:0  Shares:1.21 Total:12,570 BH:13,135.35  Correct
# date: 7/14/2020   Close: 10,489  Forecast: 10,345  Cash:0  Shares:1.21 Total:12,689 BH:13,258.91  Correct
# selling 1.21 shares at 10,489
# date: 7/15/2020   Close: 10,550  Forecast: 10,524  Cash:12,570  Shares:0.00 Total:12,570 BH:13,337.17  Correct
# buying 1.20 shares at 10,550
# date: 7/16/2020   Close: 10,474  Forecast: 10,543  Cash:0  Shares:1.20 Total:12,553 BH:13,240.26  Correct
# selling 1.20 shares at 10,474
# date: 7/17/2020   Close: 10,503  Forecast: 10,486  Cash:12,645  Shares:0.00 Total:12,645 BH:13,277.38  Should be invested
# buying 1.21 shares at 10,503
# date: 7/20/2020   Close: 10,767  Forecast: 10,479  Cash:0  Shares:1.21 Total:12,999 BH:13,610.98  Should be cash
# selling 1.21 shares at 10,767
# date: 7/21/2020   Close: 10,680  Forecast: 10,808  Cash:12,680  Shares:0.00 Total:12,680 BH:13,501.35  Should be invested
# buying 1.18 shares at 10,680
# date: 7/22/2020   Close: 10,706  Forecast: 10,699  Cash:0  Shares:1.18 Total:12,608 BH:13,533.92  Should be cash
# date: 7/23/2020   Close: 10,461  Forecast: 10,667  Cash:0  Shares:1.18 Total:12,320 BH:13,224.58  Should be cash
# selling 1.18 shares at 10,461
# date: 7/24/2020   Close: 10,363  Forecast: 10,492  Cash:12,608  Shares:0.00 Total:12,608 BH:13,100.39  Should be invested
# buying 1.21 shares at 10,363
# date: 7/27/2020   Close: 10,536  Forecast: 10,402  Cash:0  Shares:1.21 Total:12,699 BH:13,319.20  Should be cash
# date: 7/28/2020   Close: 10,402  Forecast: 10,475  Cash:0  Shares:1.21 Total:12,537 BH:13,149.58  Correct
# selling 1.21 shares at 10,402
# date: 7/29/2020   Close: 10,543  Forecast: 10,513  Cash:12,699  Shares:0.00 Total:12,699 BH:13,327.63  Should be invested
# buying 1.22 shares at 10,543
# date: 7/30/2020   Close: 10,588  Forecast: 10,487  Cash:0  Shares:1.22 Total:12,925 BH:13,384.35  Correct
# selling 1.22 shares at 10,588
# date: 7/31/2020   Close: 10,745  Forecast: 10,567  Cash:12,870  Shares:0.00 Total:12,870 BH:13,583.40  Should be invested
# date: 8/3/2020   Close: 10,903  Forecast: 10,827  Cash:12,870  Shares:0.00 Total:12,870 BH:13,782.54  Should be invested
# buying 1.20 shares at 10,903
# date: 8/4/2020   Close: 10,941  Forecast: 10,839  Cash:0  Shares:1.20 Total:13,105 BH:13,831.04  Correct
# selling 1.20 shares at 10,941
# date: 8/5/2020   Close: 10,998  Forecast: 10,941  Cash:13,059  Shares:0.00 Total:13,059 BH:13,903.39  Should be invested
# date: 8/6/2020   Close: 11,108  Forecast: 11,006  Cash:13,059  Shares:0.00 Total:13,059 BH:14,042.03  Correct
# buying 1.19 shares at 11,108
# date: 8/7/2020   Close: 11,011  Forecast: 11,063  Cash:0  Shares:1.19 Total:13,074 BH:13,919.29  Should be cash
# selling 1.19 shares at 11,011
# date: 8/10/2020   Close: 10,968  Forecast: 11,044  Cash:13,189  Shares:0.00 Total:13,189 BH:13,865.41  Correct
# buying 1.20 shares at 10,968
# date: 8/11/2020   Close: 10,783  Forecast: 10,933  Cash:0  Shares:1.20 Total:12,916 BH:13,630.87  Correct
# selling 1.20 shares at 10,783
# date: 8/12/2020   Close: 11,012  Forecast: 10,791  Cash:13,138  Shares:0.00 Total:13,138 BH:13,920.88  Should be invested
# buying 1.22 shares at 11,012
# date: 8/13/2020   Close: 11,042  Forecast: 11,014  Cash:0  Shares:1.22 Total:13,455 BH:13,959.14  Should be cash
# date: 8/14/2020   Close: 11,019  Forecast: 11,048  Cash:0  Shares:1.22 Total:13,426 BH:13,929.81  Correct
# date: 8/17/2020   Close: 11,130  Forecast: 11,038  Cash:0  Shares:1.22 Total:13,561 BH:14,069.41  Correct
# date: 8/18/2020   Close: 11,211  Forecast: 11,145  Cash:0  Shares:1.22 Total:13,660 BH:14,171.94  Should be cash
# date: 8/19/2020   Close: 11,146  Forecast: 11,209  Cash:0  Shares:1.22 Total:13,581 BH:14,090.55  Correct
# selling 1.22 shares at 11,146
# date: 8/20/2020   Close: 11,265  Forecast: 11,172  Cash:13,660  Shares:0.00 Total:13,660 BH:14,240.34  Should be invested
# buying 1.23 shares at 11,265
# date: 8/21/2020   Close: 11,312  Forecast: 11,211  Cash:0  Shares:1.23 Total:13,862 BH:14,299.57  Correct
# selling 1.23 shares at 11,312
# date: 8/24/2020   Close: 11,380  Forecast: 11,318  Cash:13,805  Shares:0.00 Total:13,805 BH:14,385.43  Should be invested
# buying 1.22 shares at 11,380
# date: 8/25/2020   Close: 11,466  Forecast: 11,349  Cash:0  Shares:1.22 Total:13,994 BH:14,495.09  Correct
# selling 1.22 shares at 11,466
# date: 8/26/2020   Close: 11,665  Forecast: 11,476  Cash:13,888  Shares:0.00 Total:13,888 BH:14,746.13  Correct
# buying 1.21 shares at 11,665
# date: 8/27/2020   Close: 11,625  Forecast: 11,676  Cash:0  Shares:1.21 Total:14,080 BH:14,695.92  Correct
# date: 8/28/2020   Close: 11,696  Forecast: 11,618  Cash:0  Shares:1.21 Total:14,165 BH:14,784.78  Correct
# selling 1.21 shares at 11,696
# date: 8/31/2020   Close: 11,775  Forecast: 11,709  Cash:14,080  Shares:0.00 Total:14,080 BH:14,885.69  Should be invested
# buying 1.20 shares at 11,775
# date: 9/1/2020   Close: 11,940  Forecast: 11,770  Cash:0  Shares:1.20 Total:14,374 BH:15,093.27  Correct
# selling 1.20 shares at 11,940
# date: 9/2/2020   Close: 12,056  Forecast: 11,934  Cash:14,176  Shares:0.00 Total:14,176 BH:15,240.89  Correct
# date: 9/3/2020   Close: 11,458  Forecast: 12,033  Cash:14,176  Shares:0.00 Total:14,176 BH:14,484.51  Correct
# date: 9/4/2020   Close: 11,313  Forecast: 11,422  Cash:14,176  Shares:0.00 Total:14,176 BH:14,301.25  Correct
# date: 9/8/2020   Close: 10,848  Forecast: 11,300  Cash:14,176  Shares:0.00 Total:14,176 BH:13,712.87  Should be invested
# date: 9/9/2020   Close: 11,142  Forecast: 10,840  Cash:14,176  Shares:0.00 Total:14,176 BH:14,084.36  Correct
# date: 9/10/2020   Close: 10,920  Forecast: 11,156  Cash:14,176  Shares:0.00 Total:14,176 BH:13,803.76  Correct
# buying 1.27 shares at 10,920
# date: 9/11/2020   Close: 10,854  Forecast: 10,910  Cash:0  Shares:1.27 Total:13,810 BH:13,720.28  Correct
# selling 1.27 shares at 10,854
# date: 9/14/2020   Close: 11,057  Forecast: 10,871  Cash:13,894  Shares:0.00 Total:13,894 BH:13,977.02  Should be invested
# buying 1.28 shares at 11,057
# date: 9/15/2020   Close: 11,190  Forecast: 11,037  Cash:0  Shares:1.28 Total:14,325 BH:14,146.00  Should be cash
# selling 1.28 shares at 11,190
# date: 9/16/2020   Close: 11,050  Forecast: 11,167  Cash:14,154  Shares:0.00 Total:14,154 BH:13,969.21  Correct
# date: 9/17/2020   Close: 10,910  Forecast: 11,069  Cash:14,154  Shares:0.00 Total:14,154 BH:13,791.99  Correct
# buying 1.28 shares at 10,910
# date: 9/18/2020   Close: 10,793  Forecast: 10,898  Cash:0  Shares:1.28 Total:13,825 BH:13,644.09  Should be cash
# selling 1.28 shares at 10,793
# date: 9/21/2020   Close: 10,779  Forecast: 10,746  Cash:13,974  Shares:0.00 Total:13,974 BH:13,625.79  Should be invested
# date: 9/22/2020   Close: 10,964  Forecast: 10,824  Cash:13,974  Shares:0.00 Total:13,974 BH:13,859.45  Correct
# buying 1.30 shares at 10,964
# date: 9/23/2020   Close: 10,633  Forecast: 10,993  Cash:0  Shares:1.30 Total:13,785 BH:13,441.46  Correct
# date: 9/24/2020   Close: 10,672  Forecast: 10,625  Cash:0  Shares:1.30 Total:13,836 BH:13,491.12  Correct
# selling 1.30 shares at 10,672
# date: 9/25/2020   Close: 10,914  Forecast: 10,672  Cash:13,785  Shares:0.00 Total:13,785 BH:13,796.14  Should be invested
# buying 1.29 shares at 10,914
# date: 9/28/2020   Close: 11,118  Forecast: 10,945  Cash:0  Shares:1.29 Total:14,361 BH:14,053.98  Should be cash
# date: 9/29/2020   Close: 11,085  Forecast: 11,047  Cash:0  Shares:1.29 Total:14,319 BH:14,013.18  Correct
# selling 1.29 shares at 11,085
# date: 9/30/2020   Close: 11,168  Forecast: 11,108  Cash:14,361  Shares:0.00 Total:14,361 BH:14,117.16  Should be invested
# buying 1.30 shares at 11,168
# date: 10/1/2020   Close: 11,327  Forecast: 11,200  Cash:0  Shares:1.30 Total:14,673 BH:14,318.16  Should be cash
# date: 10/2/2020   Close: 11,075  Forecast: 11,307  Cash:0  Shares:1.30 Total:14,347 BH:14,000.24  Correct
# selling 1.30 shares at 11,075
# date: 10/5/2020   Close: 11,332  Forecast: 11,046  Cash:14,673  Shares:0.00 Total:14,673 BH:14,325.72  Correct
# date: 10/6/2020   Close: 11,155  Forecast: 11,359  Cash:14,673  Shares:0.00 Total:14,673 BH:14,100.84  Should be invested
# buying 1.29 shares at 11,155
# date: 10/7/2020   Close: 11,365  Forecast: 11,113  Cash:0  Shares:1.29 Total:14,715 BH:14,366.31  Correct
# selling 1.29 shares at 11,365
# date: 10/8/2020   Close: 11,421  Forecast: 11,349  Cash:14,443  Shares:0.00 Total:14,443 BH:14,437.58  Should be invested
# date: 10/9/2020   Close: 11,580  Forecast: 11,451  Cash:14,443  Shares:0.00 Total:14,443 BH:14,638.53  Should be invested
# buying 1.26 shares at 11,580
# date: 10/12/2020   Close: 11,876  Forecast: 11,593  Cash:0  Shares:1.26 Total:15,019 BH:15,013.12  Should be cash
# date: 10/13/2020   Close: 11,864  Forecast: 11,880  Cash:0  Shares:1.26 Total:15,003 BH:14,997.49  Should be cash
# date: 10/14/2020   Close: 11,769  Forecast: 11,855  Cash:0  Shares:1.26 Total:14,883 BH:14,877.18  Should be cash
# selling 1.26 shares at 11,769
# date: 10/15/2020   Close: 11,714  Forecast: 11,745  Cash:15,003  Shares:0.00 Total:15,003 BH:14,807.83  Correct
# date: 10/16/2020   Close: 11,672  Forecast: 11,727  Cash:15,003  Shares:0.00 Total:15,003 BH:14,754.35  Correct
# buying 1.28 shares at 11,672
# date: 10/19/2020   Close: 11,479  Forecast: 11,666  Cash:0  Shares:1.28 Total:14,702 BH:14,510.78  Correct
# selling 1.28 shares at 11,479
# date: 10/20/2020   Close: 11,516  Forecast: 11,529  Cash:14,949  Shares:0.00 Total:14,949 BH:14,558.32  Correct
# buying 1.30 shares at 11,516
# date: 10/21/2020   Close: 11,485  Forecast: 11,494  Cash:0  Shares:1.30 Total:14,956 BH:14,518.12  Correct
# selling 1.30 shares at 11,485
# date: 10/22/2020   Close: 11,506  Forecast: 11,484  Cash:14,998  Shares:0.00 Total:14,998 BH:14,545.07  Should be invested
# date: 10/23/2020   Close: 11,548  Forecast: 11,529  Cash:14,998  Shares:0.00 Total:14,998 BH:14,598.51  Correct
# buying 1.30 shares at 11,548
# date: 10/26/2020   Close: 11,359  Forecast: 11,575  Cash:0  Shares:1.30 Total:14,806 BH:14,359.16  Correct
# date: 10/27/2020   Close: 11,431  Forecast: 11,384  Cash:0  Shares:1.30 Total:14,900 BH:14,450.69  Should be cash
# date: 10/28/2020   Close: 11,005  Forecast: 11,467  Cash:0  Shares:1.30 Total:14,344 BH:13,911.57  Correct
# date: 10/29/2020   Close: 11,186  Forecast: 10,961  Cash:0  Shares:1.30 Total:14,580 BH:14,140.02  Should be cash
# selling 1.30 shares at 11,186
# date: 10/30/2020   Close: 10,912  Forecast: 11,233  Cash:14,344  Shares:0.00 Total:14,344 BH:13,793.65  Should be invested
# buying 1.28 shares at 10,912
# date: 11/2/2020   Close: 10,958  Forecast: 10,894  Cash:0  Shares:1.28 Total:14,052 BH:13,851.82  Correct
# selling 1.28 shares at 10,958
# date: 11/3/2020   Close: 11,161  Forecast: 10,979  Cash:13,993  Shares:0.00 Total:13,993 BH:14,108.39  Should be invested
# buying 1.28 shares at 11,161
# date: 11/4/2020   Close: 11,591  Forecast: 11,168  Cash:0  Shares:1.28 Total:14,802 BH:14,652.23  Correct
# date: 11/5/2020   Close: 11,891  Forecast: 11,572  Cash:0  Shares:1.28 Total:15,185 BH:15,031.66  Correct
# selling 1.28 shares at 11,891
# date: 11/6/2020   Close: 11,895  Forecast: 11,882  Cash:14,802  Shares:0.00 Total:14,802 BH:15,037.10  Correct
# date: 11/9/2020   Close: 11,714  Forecast: 11,868  Cash:14,802  Shares:0.00 Total:14,802 BH:14,807.72  Correct
# date: 11/10/2020   Close: 11,554  Forecast: 11,654  Cash:14,802  Shares:0.00 Total:14,802 BH:14,605.56  Should be invested
# date: 11/11/2020   Close: 11,786  Forecast: 11,563  Cash:14,802  Shares:0.00 Total:14,802 BH:14,899.56  Correct
# buying 1.28 shares at 11,786
# date: 11/12/2020   Close: 11,710  Forecast: 11,827  Cash:0  Shares:1.28 Total:15,001 BH:14,802.42  Correct
# date: 11/13/2020   Close: 11,829  Forecast: 11,708  Cash:0  Shares:1.28 Total:15,155 BH:14,953.74  Correct
# selling 1.28 shares at 11,829
# date: 11/16/2020   Close: 11,924  Forecast: 11,827  Cash:15,001  Shares:0.00 Total:15,001 BH:15,073.63  Correct
# date: 11/17/2020   Close: 11,899  Forecast: 11,933  Cash:15,001  Shares:0.00 Total:15,001 BH:15,042.29  Correct
# buying 1.26 shares at 11,899
# date: 11/18/2020   Close: 11,802  Forecast: 11,841  Cash:0  Shares:1.26 Total:14,847 BH:14,918.74  Correct
# selling 1.26 shares at 11,802
# date: 11/19/2020   Close: 11,905  Forecast: 11,752  Cash:14,970  Shares:0.00 Total:14,970 BH:15,049.08  Correct
# date: 11/20/2020   Close: 11,855  Forecast: 11,917  Cash:14,970  Shares:0.00 Total:14,970 BH:14,986.20  Should be invested
# buying 1.26 shares at 11,855
# date: 11/23/2020   Close: 11,881  Forecast: 11,830  Cash:0  Shares:1.26 Total:14,940 BH:15,018.64  Correct
# selling 1.26 shares at 11,881
# ...
# date: 6/2/2022   Close: 12,317  Forecast: 12,024  Cash:16,944  Shares:0.00 Total:16,944 BH:15,570.14  Correct
# buying 1.41 shares at 12,317
# date: 6/3/2022   Close: 12,013  Forecast: 12,356  Cash:0  Shares:1.41 Total:16,970 BH:15,185.63  Correct
# date: 6/6/2022   Close: 12,061  Forecast: 12,081  Cash:0  Shares:1.41 Total:17,038 BH:15,247.12  Correct
# date: 6/7/2022   Close: 12,175  Forecast: 12,111  Cash:0  Shares:1.41 Total:17,199 BH:15,391.05  Should be cash
# date: 6/8/2022   Close: 12,086  Forecast: 12,197  Cash:0  Shares:1.41 Total:17,074 BH:15,278.59  Should be cash
# date: 6/9/2022   Close: 11,754  Forecast: 12,062  Cash:0  Shares:1.41 Total:16,605 BH:14,858.85  Should be cash
# selling 1.41 shares at 11,754
# date: 6/10/2022   Close: 11,340  Forecast: 11,771  Cash:17,074  Shares:0.00 Total:17,074 BH:14,335.24  Correct
# buying 1.45 shares at 11,340
# date: 6/13/2022   Close: 10,809  Forecast: 11,336  Cash:0  Shares:1.45 Total:15,701 BH:13,664.25  Correct
# selling 1.45 shares at 10,809
# date: 6/14/2022   Close: 10,828  Forecast: 10,817  Cash:16,472  Shares:0.00 Total:16,472 BH:13,688.42  Should be invested
# buying 1.52 shares at 10,828
# date: 6/15/2022   Close: 11,099  Forecast: 10,835  Cash:0  Shares:1.52 Total:16,914 BH:14,030.75  Should be cash
# date: 6/16/2022   Close: 10,646  Forecast: 11,104  Cash:0  Shares:1.52 Total:16,223 BH:13,458.04  Correct
# date: 6/17/2022   Close: 10,798  Forecast: 10,668  Cash:0  Shares:1.52 Total:16,455 BH:13,650.50  Correct
# date: 6/21/2022   Close: 11,069  Forecast: 10,754  Cash:0  Shares:1.52 Total:16,868 BH:13,993.01  Should be cash
# selling 1.52 shares at 11,069
# date: 6/22/2022   Close: 11,053  Forecast: 11,186  Cash:16,455  Shares:0.00 Total:16,455 BH:13,972.51  Should be invested
# buying 1.49 shares at 11,053
# date: 6/23/2022   Close: 11,232  Forecast: 11,083  Cash:0  Shares:1.49 Total:16,697 BH:14,198.93  Correct
# date: 6/24/2022   Close: 11,608  Forecast: 11,229  Cash:0  Shares:1.49 Total:17,256 BH:14,673.52  Should be cash
# selling 1.49 shares at 11,608
# date: 6/27/2022   Close: 11,525  Forecast: 11,611  Cash:16,697  Shares:0.00 Total:16,697 BH:14,568.51  Correct
# buying 1.44 shares at 11,525
# date: 6/28/2022   Close: 11,182  Forecast: 11,666  Cash:0  Shares:1.44 Total:16,085 BH:14,134.90  Should be cash
# date: 6/29/2022   Close: 11,178  Forecast: 11,086  Cash:0  Shares:1.44 Total:16,079 BH:14,130.29  Should be cash
# selling 1.44 shares at 11,178
# date: 6/30/2022   Close: 11,029  Forecast: 11,205  Cash:16,085  Shares:0.00 Total:16,085 BH:13,941.74  Should be invested
# buying 1.44 shares at 11,029
# date: 7/1/2022   Close: 11,128  Forecast: 11,147  Cash:0  Shares:1.44 Total:16,013 BH:14,067.03  Correct
# date: 7/5/2022   Close: 11,322  Forecast: 11,108  Cash:0  Shares:1.44 Total:16,292 BH:14,312.76  Correct
# selling 1.44 shares at 11,322
# date: 7/6/2022   Close: 11,362  Forecast: 11,080  Cash:16,013  Shares:0.00 Total:16,013 BH:14,362.83  Should be invested
# date: 7/7/2022   Close: 11,621  Forecast: 11,525  Cash:16,013  Shares:0.00 Total:16,013 BH:14,690.88  Should be invested
# buying 1.41 shares at 11,621
# date: 7/8/2022   Close: 11,635  Forecast: 11,644  Cash:0  Shares:1.41 Total:16,398 BH:14,708.52  Should be cash
# date: 7/11/2022   Close: 11,373  Forecast: 11,534  Cash:0  Shares:1.41 Total:16,028 BH:14,376.42  Should be cash
# selling 1.41 shares at 11,373
# date: 7/12/2022   Close: 11,265  Forecast: 11,400  Cash:16,398  Shares:0.00 Total:16,398 BH:14,240.06  Correct
# buying 1.44 shares at 11,265
# date: 7/13/2022   Close: 11,248  Forecast: 11,420  Cash:0  Shares:1.44 Total:16,218 BH:14,218.38  Correct
# date: 7/14/2022   Close: 11,251  Forecast: 11,239  Cash:0  Shares:1.44 Total:16,223 BH:14,222.95  Correct
# selling 1.44 shares at 11,251
# date: 7/15/2022   Close: 11,452  Forecast: 11,165  Cash:16,218  Shares:0.00 Total:16,218 BH:14,477.33  Correct
# date: 7/18/2022   Close: 11,360  Forecast: 11,504  Cash:16,218  Shares:0.00 Total:16,218 BH:14,360.56  Should be invested
# buying 1.42 shares at 11,360
# date: 7/19/2022   Close: 11,713  Forecast: 11,408  Cash:0  Shares:1.42 Total:16,587 BH:14,806.92  Correct
# date: 7/20/2022   Close: 11,898  Forecast: 11,753  Cash:0  Shares:1.42 Total:16,848 BH:15,040.16  Correct
# date: 7/21/2022   Close: 12,060  Forecast: 11,987  Cash:0  Shares:1.42 Total:17,078 BH:15,244.89  Should be cash
# date: 7/22/2022   Close: 11,834  Forecast: 11,980  Cash:0  Shares:1.42 Total:16,758 BH:14,959.83  Should be cash
# selling 1.42 shares at 11,834
# date: 7/25/2022   Close: 11,783  Forecast: 11,889  Cash:17,078  Shares:0.00 Total:17,078 BH:14,894.81  Correct
# buying 1.44 shares at 11,783
# date: 7/26/2022   Close: 11,563  Forecast: 11,872  Cash:0  Shares:1.44 Total:16,686 BH:14,616.57  Correct
# date: 7/27/2022   Close: 12,032  Forecast: 11,722  Cash:0  Shares:1.44 Total:17,364 BH:15,210.52  Correct
# date: 7/28/2022   Close: 12,163  Forecast: 11,941  Cash:0  Shares:1.44 Total:17,552 BH:15,375.07  Correct
# selling 1.44 shares at 12,163
# date: 7/29/2022   Close: 12,391  Forecast: 12,191  Cash:17,364  Shares:0.00 Total:17,364 BH:15,663.42  Correct
# buying 1.43 shares at 12,391
# date: 8/1/2022   Close: 12,369  Forecast: 12,431  Cash:0  Shares:1.43 Total:17,658 BH:15,635.98  Should be cash
# date: 8/2/2022   Close: 12,349  Forecast: 12,389  Cash:0  Shares:1.43 Total:17,629 BH:15,610.42  Correct
# date: 8/3/2022   Close: 12,668  Forecast: 12,334  Cash:0  Shares:1.43 Total:18,085 BH:16,014.18  Correct
# selling 1.43 shares at 12,668
# date: 8/4/2022   Close: 12,721  Forecast: 12,652  Cash:17,629  Shares:0.00 Total:17,629 BH:16,080.44  Correct
# date: 8/5/2022   Close: 12,658  Forecast: 12,670  Cash:17,629  Shares:0.00 Total:17,629 BH:16,000.77  Correct
# date: 8/8/2022   Close: 12,644  Forecast: 12,670  Cash:17,629  Shares:0.00 Total:17,629 BH:15,984.22  Correct
# buying 1.39 shares at 12,644
# date: 8/9/2022   Close: 12,494  Forecast: 12,604  Cash:0  Shares:1.39 Total:17,402 BH:15,793.93  Correct
# selling 1.39 shares at 12,494
# date: 8/10/2022   Close: 12,855  Forecast: 12,461  Cash:17,611  Shares:0.00 Total:17,611 BH:16,250.12  Correct
# date: 8/11/2022   Close: 12,780  Forecast: 12,839  Cash:17,611  Shares:0.00 Total:17,611 BH:16,155.45  Should be invested
# date: 8/12/2022   Close: 13,047  Forecast: 12,715  Cash:17,611  Shares:0.00 Total:17,611 BH:16,493.32  Should be invested
# date: 8/15/2022   Close: 13,128  Forecast: 13,042  Cash:17,611  Shares:0.00 Total:17,611 BH:16,595.54  Correct
# date: 8/16/2022   Close: 13,103  Forecast: 13,174  Cash:17,611  Shares:0.00 Total:17,611 BH:16,563.30  Correct
# buying 1.34 shares at 13,103
# date: 8/17/2022   Close: 12,938  Forecast: 13,097  Cash:0  Shares:1.34 Total:17,356 BH:16,355.44  Correct
# selling 1.34 shares at 12,938
# date: 8/18/2022   Close: 12,965  Forecast: 12,926  Cash:17,577  Shares:0.00 Total:17,577 BH:16,389.85  Correct
# date: 8/19/2022   Close: 12,705  Forecast: 12,990  Cash:17,577  Shares:0.00 Total:17,577 BH:16,061.03  Correct
# buying 1.36 shares at 12,705
# date: 8/22/2022   Close: 12,382  Forecast: 12,658  Cash:0  Shares:1.36 Total:16,786 BH:15,651.89  Should be cash
# selling 1.36 shares at 12,382
# date: 8/23/2022   Close: 12,381  Forecast: 12,393  Cash:17,224  Shares:0.00 Total:17,224 BH:15,651.55  Should be invested
# buying 1.39 shares at 12,381
# date: 8/24/2022   Close: 12,432  Forecast: 12,448  Cash:0  Shares:1.39 Total:17,294 BH:15,715.05  Correct
# date: 8/25/2022   Close: 12,639  Forecast: 12,445  Cash:0  Shares:1.39 Total:17,583 BH:15,977.66  Should be cash
# date: 8/26/2022   Close: 12,142  Forecast: 12,588  Cash:0  Shares:1.39 Total:16,891 BH:15,348.68  Should be cash
# selling 1.39 shares at 12,142
# date: 8/29/2022   Close: 12,018  Forecast: 12,143  Cash:17,583  Shares:0.00 Total:17,583 BH:15,191.88  Correct
# buying 1.45 shares at 12,018
# date: 8/30/2022   Close: 11,883  Forecast: 12,036  Cash:0  Shares:1.45 Total:17,208 BH:15,021.81  Should be cash
# date: 8/31/2022   Close: 11,816  Forecast: 11,875  Cash:0  Shares:1.45 Total:17,112 BH:14,937.19  Should be cash
# selling 1.45 shares at 11,816
# date: 9/1/2022   Close: 11,785  Forecast: 11,815  Cash:17,208  Shares:0.00 Total:17,208 BH:14,897.92  Correct
# date: 9/2/2022   Close: 11,631  Forecast: 11,837  Cash:17,208  Shares:0.00 Total:17,208 BH:14,702.90  Correct
# buying 1.46 shares at 11,631
# date: 9/6/2022   Close: 11,545  Forecast: 11,656  Cash:0  Shares:1.46 Total:16,858 BH:14,594.25  Correct
# date: 9/7/2022   Close: 11,792  Forecast: 11,537  Cash:0  Shares:1.46 Total:17,218 BH:14,906.47  Correct
# selling 1.46 shares at 11,792
# date: 9/8/2022   Close: 11,862  Forecast: 11,834  Cash:16,858  Shares:0.00 Total:16,858 BH:14,995.25  Should be invested
# buying 1.43 shares at 11,862
# date: 9/9/2022   Close: 12,112  Forecast: 11,874  Cash:0  Shares:1.43 Total:17,316 BH:15,311.51  Correct
# date: 9/12/2022   Close: 12,266  Forecast: 12,086  Cash:0  Shares:1.43 Total:17,536 BH:15,506.32  Should be cash
# selling 1.43 shares at 12,266
# date: 9/13/2022   Close: 11,634  Forecast: 12,295  Cash:17,316  Shares:0.00 Total:17,316 BH:14,706.32  Should be invested
# buying 1.41 shares at 11,634
# date: 9/14/2022   Close: 11,720  Forecast: 11,620  Cash:0  Shares:1.41 Total:16,544 BH:14,815.18  Should be cash
# selling 1.41 shares at 11,720
# date: 9/15/2022   Close: 11,552  Forecast: 11,714  Cash:16,422  Shares:0.00 Total:16,422 BH:14,603.66  Correct
# date: 9/16/2022   Close: 11,448  Forecast: 11,555  Cash:16,422  Shares:0.00 Total:16,422 BH:14,472.25  Should be invested
# buying 1.42 shares at 11,448
# date: 9/19/2022   Close: 11,535  Forecast: 11,384  Cash:0  Shares:1.42 Total:16,398 BH:14,581.74  Should be cash
# selling 1.42 shares at 11,535
# date: 9/20/2022   Close: 11,425  Forecast: 11,633  Cash:16,275  Shares:0.00 Total:16,275 BH:14,442.73  Correct
# buying 1.41 shares at 11,425
# date: 9/21/2022   Close: 11,220  Forecast: 11,476  Cash:0  Shares:1.41 Total:15,830 BH:14,183.76  Should be cash
# date: 9/22/2022   Close: 11,067  Forecast: 11,201  Cash:0  Shares:1.41 Total:15,614 BH:13,989.87  Should be cash
# selling 1.41 shares at 11,067
# date: 9/23/2022   Close: 10,868  Forecast: 11,073  Cash:15,830  Shares:0.00 Total:15,830 BH:13,738.46  Correct
# buying 1.43 shares at 10,868
# date: 9/26/2022   Close: 10,803  Forecast: 10,873  Cash:0  Shares:1.43 Total:15,453 BH:13,656.28  Correct
# date: 9/27/2022   Close: 10,830  Forecast: 10,668  Cash:0  Shares:1.43 Total:15,491 BH:13,689.88  Correct
# selling 1.43 shares at 10,830
# date: 9/28/2022   Close: 11,052  Forecast: 10,901  Cash:15,453  Shares:0.00 Total:15,453 BH:13,970.69  Correct
# buying 1.43 shares at 11,052
# date: 9/29/2022   Close: 10,738  Forecast: 11,129  Cash:0  Shares:1.43 Total:15,322 BH:13,573.59  Should be cash
# date: 9/30/2022   Close: 10,576  Forecast: 10,719  Cash:0  Shares:1.43 Total:15,091 BH:13,368.94  Correct
# selling 1.43 shares at 10,576
# date: 10/3/2022   Close: 10,815  Forecast: 10,533  Cash:15,322  Shares:0.00 Total:15,322 BH:13,672.09  Should be invested
# date: 10/4/2022   Close: 11,176  Forecast: 10,846  Cash:15,322  Shares:0.00 Total:15,322 BH:14,128.42  Correct
# buying 1.42 shares at 11,176
# date: 10/5/2022   Close: 11,149  Forecast: 11,117  Cash:0  Shares:1.42 Total:15,794 BH:14,093.31  Should be cash
# selling 1.42 shares at 11,149
# date: 10/6/2022   Close: 11,073  Forecast: 11,129  Cash:15,833  Shares:0.00 Total:15,833 BH:13,998.08  Correct
# date: 10/7/2022   Close: 10,652  Forecast: 11,124  Cash:15,833  Shares:0.00 Total:15,833 BH:13,466.00  Correct
# buying 1.43 shares at 10,652
# date: 10/10/2022   Close: 10,542  Forecast: 10,729  Cash:0  Shares:1.43 Total:15,074 BH:13,326.57  Should be cash
# date: 10/11/2022   Close: 10,426  Forecast: 10,573  Cash:0  Shares:1.43 Total:14,908 BH:13,180.04  Should be cash
# date: 10/12/2022   Close: 10,417  Forecast: 10,389  Cash:0  Shares:1.43 Total:14,895 BH:13,168.55  Correct
# selling 1.43 shares at 10,417
# date: 10/13/2022   Close: 10,649  Forecast: 10,426  Cash:14,908  Shares:0.00 Total:14,908 BH:13,461.89  Correct
# buying 1.43 shares at 10,649
# date: 10/14/2022   Close: 10,321  Forecast: 10,633  Cash:0  Shares:1.43 Total:14,771 BH:13,047.56  Correct
# selling 1.43 shares at 10,321
# date: 10/17/2022   Close: 10,676  Forecast: 10,321  Cash:15,240  Shares:0.00 Total:15,240 BH:13,495.58  Should be invested
# date: 10/18/2022   Close: 10,772  Forecast: 10,768  Cash:15,240  Shares:0.00 Total:15,240 BH:13,617.70  Correct
# buying 1.43 shares at 10,772
# date: 10/19/2022   Close: 10,681  Forecast: 10,707  Cash:0  Shares:1.43 Total:15,247 BH:13,501.53  Should be cash
# selling 1.43 shares at 10,681
# date: 10/20/2022   Close: 10,615  Forecast: 10,685  Cash:15,378  Shares:0.00 Total:15,378 BH:13,418.52  Should be invested
# buying 1.44 shares at 10,615
# date: 10/21/2022   Close: 10,860  Forecast: 10,682  Cash:0  Shares:1.44 Total:15,636 BH:13,728.08  Correct
# date: 10/24/2022   Close: 10,953  Forecast: 10,871  Cash:0  Shares:1.44 Total:15,770 BH:13,845.50  Correct
# date: 10/25/2022   Close: 11,199  Forecast: 10,967  Cash:0  Shares:1.44 Total:16,124 BH:14,157.12  Should be cash
# date: 10/26/2022   Close: 10,971  Forecast: 11,211  Cash:0  Shares:1.44 Total:15,796 BH:13,868.74  Should be cash
# date: 10/27/2022   Close: 10,793  Forecast: 10,928  Cash:0  Shares:1.44 Total:15,539 BH:13,643.32  Correct
# selling 1.44 shares at 10,793
# date: 10/28/2022   Close: 11,102  Forecast: 10,771  Cash:15,796  Shares:0.00 Total:15,796 BH:14,034.92  Correct
# date: 10/31/2022   Close: 10,988  Forecast: 11,113  Cash:15,796  Shares:0.00 Total:15,796 BH:13,890.43  Correct
# buying 1.42 shares at 10,988
# date: 11/1/2022   Close: 10,891  Forecast: 10,952  Cash:0  Shares:1.42 Total:15,495 BH:13,767.43  Should be cash
# selling 1.42 shares at 10,891
# date: 11/2/2022   Close: 10,525  Forecast: 10,876  Cash:15,633  Shares:0.00 Total:15,633 BH:13,304.70  Correct
# date: 11/3/2022   Close: 10,343  Forecast: 10,513  Cash:15,633  Shares:0.00 Total:15,633 BH:13,074.80  Should be invested
# date: 11/4/2022   Close: 10,475  Forecast: 10,324  Cash:15,633  Shares:0.00 Total:15,633 BH:13,242.06  Should be invested
# date: 11/7/2022   Close: 10,565  Forecast: 10,443  Cash:15,633  Shares:0.00 Total:15,633 BH:13,354.91  Should be invested
# date: 11/8/2022   Close: 10,616  Forecast: 10,581  Cash:15,633  Shares:0.00 Total:15,633 BH:13,420.24  Correct
# buying 1.48 shares at 10,616
# date: 11/9/2022   Close: 10,353  Forecast: 10,614  Cash:0  Shares:1.48 Total:15,321 BH:13,087.73  Correct
# selling 1.48 shares at 10,353
# date: 11/10/2022   Close: 11,114  Forecast: 10,371  Cash:15,710  Shares:0.00 Total:15,710 BH:14,049.71  Should be invested
# buying 1.52 shares at 11,114
# date: 11/11/2022   Close: 11,323  Forecast: 11,049  Cash:0  Shares:1.52 Total:17,182 BH:14,314.14  Should be cash
# selling 1.52 shares at 11,323
# date: 11/14/2022   Close: 11,196  Forecast: 11,319  Cash:16,865  Shares:0.00 Total:16,865 BH:14,153.46  Should be invested
# date: 11/15/2022   Close: 11,358  Forecast: 11,228  Cash:16,865  Shares:0.00 Total:16,865 BH:14,358.49  Correct
# buying 1.51 shares at 11,358
# date: 11/16/2022   Close: 11,184  Forecast: 11,326  Cash:0  Shares:1.51 Total:16,846 BH:14,137.58  Should be cash
# selling 1.51 shares at 11,184
# date: 11/17/2022   Close: 11,145  Forecast: 11,243  Cash:17,109  Shares:0.00 Total:17,109 BH:14,088.66  Should be invested
# buying 1.53 shares at 11,145
# date: 11/18/2022   Close: 11,146  Forecast: 11,183  Cash:0  Shares:1.53 Total:17,051 BH:14,090.05  Should be cash
# date: 11/21/2022   Close: 11,025  Forecast: 11,103  Cash:0  Shares:1.53 Total:16,865 BH:13,936.39  Correct
# selling 1.53 shares at 11,025
# date: 11/22/2022   Close: 11,174  Forecast: 11,031  Cash:17,051  Shares:0.00 Total:17,051 BH:14,125.89  Should be invested
# buying 1.55 shares at 11,174
# date: 11/23/2022   Close: 11,285  Forecast: 11,193  Cash:0  Shares:1.55 Total:17,455 BH:14,266.09  Should be cash
# date: 11/25/2022   Close: 11,226  Forecast: 11,277  Cash:0  Shares:1.55 Total:17,364 BH:14,191.56  Should be cash
# selling 1.55 shares at 11,226
#
# days correct: 467       days incorrect: 429
# total wealth: $17,455   total with B&H: $13,968
#
# Percent improvement: 24.96%
